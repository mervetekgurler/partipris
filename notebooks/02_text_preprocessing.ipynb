# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# This notebook contains the text preprocessing or data cleaning step for the Parti Pris corpus. In the previous notebook (`01_text_extraction.ipynb`), we used Gemini 2.5 to extract text and metadata from the Parti Pris corpus. We validated the OCR output for completeness and quality.
#
# In this notebook, we will extract the metadata and the full texts of the articles and clean up the texts.

# %% [markdown]
# ## Metadata

# %% [markdown]
# We will extract the metadata from the table of contents json files.
#
# This is what our metadata looks like for teh first issue (163122_1-1963-10.json).
#
# ```python
# "metadata": {
#     "volume_number": "1",
#     "issue_number": "1",
#     "season_or_month": "octobre",
#     "year": "1963",
#     "director": "",
#     "description": "revue politique et littéraire paraît chaque mois sur 64 pages",
#     "price": "Prix 50 cents 12 numéros: $5.00",
#     "editors": [
#       "André Brochu",
#       "Paul Chamberland",
#       "Pierre Maheu",
#       "André Major",
#       "Jean-Marc Piotte"
#     ],
#     "collaborators": [],
#     "administration": [
#       "Yvon Dionne",
#       "Laurent Girouard",
#       "Pierre Maheu",
#       "Robert Maheu",
#       "Gérald McKenzie",
#       "Lise Théberge"
#     ],
#     "publisher": "La Revue PARTI PRIS, inc. 790-B rue Champagneur, Montréal (8) Québec.",
#     "distributor": "Agence de Distribution Populaire, 1130 est rue Lagauchetière Montréal. Tél. LA 3-1182"
#   }
# ```
#
# We will first extract everything (metadata_unedited) and then extract a subset of this metadata that only contains temporal information, which we will later connect to our full texts.

# %%
import os
import json
import pandas as pd

toc_dir = "../data/toc_transcriptions"
processed_dir = "../data/processed"
os.makedirs(processed_dir, exist_ok=True)

# Gather all metadata
metadata_list = []
for fname in os.listdir(toc_dir):
    if fname.endswith(".json"):
        with open(os.path.join(toc_dir, fname), "r", encoding="utf-8") as f:
            toc_json = json.load(f)
            meta = toc_json.get("metadata", {})
            meta["source_file"] = fname.replace("toc_", "")  # remove 'toc_' prefix
            metadata_list.append(meta)

# Save full metadata as metadata_unedited.csv
metadata_unedited = pd.DataFrame(metadata_list)
# Move source_file to the first column
cols = ['source_file'] + [col for col in metadata_unedited.columns if col != 'source_file']
metadata_unedited = metadata_unedited[cols]
metadata_unedited.to_csv(os.path.join(processed_dir, "metadata_unedited.csv"), index=False)

# Save simplified metadata as metadata.csv
simple_cols = ["source_file", "volume_number", "issue_number", "season_or_month", "year"]
metadata = metadata_unedited[simple_cols]
metadata.to_csv(os.path.join(processed_dir, "metadata.csv"), index=False)

# %%
metadata_unedited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      39 non-null     object
#  1   volume_number    39 non-null     object
#  2   issue_number     39 non-null     object
#  3   season_or_month  39 non-null     object
#  4   year             39 non-null     object
#  5   director         39 non-null     object
#  6   description      39 non-null     object
#  7   price            39 non-null     object
#  8   editors          39 non-null     object
#  9   collaborators    39 non-null     object
#  10  administration   39 non-null     object
#  11  publisher        39 non-null     object
#  12  distributor      39 non-null     object
# dtypes: object(13)
# memory usage: 4.1+ KB

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      39 non-null     object
#  1   volume_number    39 non-null     object
#  2   issue_number     39 non-null     object
#  3   season_or_month  39 non-null     object
#  4   year             39 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Full Text Corpus

# %% [markdown]
# Now, we will extract the full text corpus and merge it with the simplified metadata. Each row in the partipris dataframe will be one article from one issue.
#
# We will use the source_file column to connect the metadata to the full text. However, since we had to split the PDFs that were too large into -A, -B, etc, we will need to create a clean source_file column. We will first extract the texts as is and save the corpus as partipris_unedited.csv. Afterwards, we will edit the source_file information and merge with the metadata to create partipris.csv.

# %%
# Like we did in the previous notebook, these 3 files are not relevant for the full text corpus
# So we will skip them during processing

skip_files = {
    "163122_1-1964-09-01.json",
    "163122_1-1964-12-01.json",
    "163122_2-1966-06.json"
}

# %%
# Step 1: read the json files from data/transcriptions and save the unedited full text corpus

transcriptions_dir = "../data/transcriptions"
processed_dir = "../data/processed"
os.makedirs(processed_dir, exist_ok=True)

json_files = [f for f in os.listdir(transcriptions_dir) if f.endswith('.json')]

data_unedited = []
for file in json_files:
    if file in skip_files:
        continue
    with open(os.path.join(transcriptions_dir, file), 'r', encoding='utf-8') as f:
        entry = json.load(f)
        if isinstance(entry, list):
            for item in entry:
                item['source_file_raw'] = file
                data_unedited.append(item)
        else:
            entry['source_file_raw'] = file
            data_unedited.append(entry)

partipris_unedited = pd.DataFrame(data_unedited)
# Move source_file_raw to the first column
cols = ['source_file_raw'] + [col for col in partipris_unedited.columns if col != 'source_file_raw']
partipris_unedited = partipris_unedited[cols]
partipris_unedited.to_csv(os.path.join(processed_dir, "partipris_unedited.csv"), index=False)

# %%
partipris_unedited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file_raw  698 non-null    object
#  1   author           698 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
# dtypes: object(5)
# memory usage: 27.4+ KB

# %%
# Step 2: Clean up source_file and prepare for merge
import re

data_clean = []
for item in data_unedited:
    # Remove -A, -B, etc. before .json for matching
    base_file = re.sub(r'-[A-Z](?=\.json$)', '', item['source_file_raw'])
    item_clean = item.copy()
    item_clean['source_file'] = base_file
    data_clean.append(item_clean)

partipris = pd.DataFrame(data_clean)
# Move source_file to the first column and drop source_file_raw
cols = ['source_file'] + [col for col in partipris.columns if col not in ['source_file', 'source_file_raw']]
partipris = partipris[cols]

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   source_file  698 non-null    object
#  1   author       698 non-null    object
#  2   title        698 non-null    object
#  3   page_range   698 non-null    object
#  4   text         698 non-null    object
# dtypes: object(5)
# memory usage: 27.4+ KB

# %%
partipris.head()
# Out:
#              source_file            author                        title  \
# 0  163122_1-1964-09.json        parti pris              manifeste 64-65
# 1  163122_1-1964-09.json     la direction.            lettre au lecteur
# 2  163122_1-1964-09.json  paul chamberland            bilan d'un combat
# 3  163122_1-1964-09.json  jean-marc piotte   autocritique de parti pris
# 4  163122_1-1964-09.json      pierre maheu  notes pour une politisation
#
#   page_range                                               text
# 0       4-17  manifeste 64-65 Toute révolution détruit l'anc...
# 1      18-19  lettre au lecteur parti pris se prépare à une ...
# 2      20-35  bilan d'un combat paul chamberland Nous lutton...
# 3      36-44  autocritique de parti pris jean-marc piotte Pi...
# 4      45-56  notes pour une politisation pierre maheu Dans ...

# %%
# Let's make sure that we have 42-3 = 39 unique source files as we intended
partipris['source_file'].nunique()
# Out:
# 39

# %%
# Step 3: Merge with metadata

# Check for matching source_file values
print("Unique source_file in partipris:", partipris['source_file'].nunique())
print("Unique source_file in metadata:", metadata['source_file'].nunique())
print("partipris source_file not in metadata:", set(partipris['source_file']) - set(metadata['source_file']))
print("metadata source_file not in partipris:", set(metadata['source_file']) - set(partipris['source_file']))
# Out:
# Unique source_file in partipris: 39
# Unique source_file in metadata: 39
# partipris source_file not in metadata: set()
# metadata source_file not in partipris: set()

# %%
# Merge on source_file
partipris = partipris.merge(metadata, on="source_file", how="left")

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      698 non-null    object
#  1   author           698 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
#  5   volume_number    698 non-null    object
#  6   issue_number     698 non-null    object
#  7   season_or_month  698 non-null    object
#  8   year             698 non-null    object
# dtypes: object(9)
# memory usage: 49.2+ KB

# %%
# Step 4: Save partipris with metadata as partipris_v1.csv

partipris.to_csv(os.path.join(processed_dir, "partipris_v1.csv"), index=False)

# %% [markdown]
# ## Data Cleaning

# %%
# Let's load the partipris_v1.csv
partipris = pd.read_csv('../data/processed/partipris_v1.csv')

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      698 non-null    object
#  1   author           695 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
#  5   volume_number    593 non-null    object
#  6   issue_number     698 non-null    object
#  7   season_or_month  698 non-null    object
#  8   year             698 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 49.2+ KB

# %% [markdown]
# We have a couple of entries with no authors and no volume numbers. It is to be expected because volume numbers did not exist for the first year of Parti Pris. Authors will be addressed later.
#
# Why did this not appear when we first loaded the JSONs?
#
# When we first create the DataFrame from JSON, all fields appear non-null because pandas automatically fills missing keys with `NaN` (null) values. After saving to CSV and reloading, these nulls become visible, as CSV requires a fixed set of columns and missing data is explicitly marked as `NaN`. This is normal behavior when working with semi-structured data like JSON.

# %% [markdown]
# ### Hyphenation and Whitespace
#
# As we briefly mentioned in the text extraction notebook, hyphens play an important role in French. There are two type of hyphen use, one serves a morphological function like connecting words in question sentences (C'est -> Est-que) and the other is hyphenation at the end of a sentence (enterprise -> enter-\nprise). We prompted the model to undo the hyphenations but it was not always successful, which we will try to edit as much as possible.
#
# Second issue that we observed consistently is occasional lack of spaces between sentences, i.e. missing whitespace. We do not know why but some sentences are merged like .....

# %%
# Let's look at hyphens that exist in the text
hyphen_rows = partipris[partipris['text'].str.contains('-', na=False)]
len(hyphen_rows)
# Out:
# 681

# %% [markdown]
# Out of 698 rows, 681 of them have hyphens.
#
# Let's print some of them:

# %%
for idx, row in hyphen_rows[['source_file', 'text']].head(10).iterrows():
    print(f"Source: {row['source_file']}\nText: {row['text']}\n{'-'*40}")
# Out:
# Source: 163122_1-1964-09.json
yeux. Il n'y a aucune fenêtre: on étouffe. On a droit à une récréation de dix minutes, qu'on va prendre dans la salle de jeu. Là il y a de l'air. Ça nous fait du bien. D'après lui, pas d'avenir ici, à moins de ramper, de se met- tre dans la manche des bosses, de stouler. Un autre gars vient nous rejoindre. Une tapette celui-là, vendeur, qui nous fait admirer la coupe de son nouvel habit. Les autres jouent au pigne-pogne ou boivent un coke. Un bonhomme, dans la trentaine, infirme, essaie de vendre des billets de loterie. Je converse avec un gars de mon âge qui se marie bientôt et qui, pour met- tre de l'argent de côté, travaille le soir après sa journée ici. Un des assistants vient nous voir durant l'après-midi. Là on peut dire que notre salaire, on ne l'a pas volé. Il ne nous quitte pas d'une semelle, nous donnant un tas de directives qui se contredisent, et il s'en va. Mon camarade me dit qu'ils sont tous comme ça, brutaux, nerveux. Je dois dire • 67 qu'ils sont vraiment accablés de travail. La nouvelle administration, selon les in- formations qu'on m'a données, fait cons- tamment pression sur les gérants et leurs assistants pour obtenir le rendement maxi- mum. Donc, pression de l'Administration sur les responsables des départements qui font pression sur leurs subalternes. Il en résulte un climat d'hostilité. Ajoutez à cela la diversité d'un personnel composé en bonne partie de femmes, donc d'éléments assez peu revendicateurs. Les vieux em- ployés, qui reçoivent enfin un salaire pres- que décent, se résignent à la situation; les vieilles filles (groupe numériquement im- portant) se contente ...
# ----------------------------------------

# %% [markdown]
# **Some examples**
#
# - je n'ai pas l'intention de **reve- nir** *là-dessus*
# - en **accomplis- sant** ensemble
# - de **désagré- gation**
# - *c'est-à-dire* réaliser une idée
#
# Bold are the hyphens at word breaks and the italic ones are legitimate hyphens in French.

# %% [markdown]
# There is an easy fix! We can distinguish between these two uses by checking if there is a space after the hyphen or not.
#
# But it is always a good idea to first make sure that we do not have other hyphen use cases.

# %%
import re

word_break_pat = re.compile(r"\w+- \w+")
in_word_pat = re.compile(r"\w+-\w+")

def print_other_hyphens(text, source_file):
    # Find all hyphens in the text
    for m in re.finditer(r"-", text):
        # Get a window around the hyphen for context
        start = max(0, m.start()-15)
        end = min(len(text), m.end()+15)
        window = text[start:end]
        # Check if this hyphen is NOT part of a word-break or in-word hyphen
        if not word_break_pat.search(window) and not in_word_pat.search(window):
            print(f"Source: {source_file}")
            print(f"Context: ...{window}...")
            print('-'*40)

# Apply to all rows with at least one hyphen
for idx, row in partipris[partipris['text'].str.contains('-', na=False)].iterrows():
    print_other_hyphens(row['text'], row['source_file'])
# Out:
# Source: 163122_1-1964-09.json
# Context: ...ion en général - le bouleversem...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...tions sociales - est un acte po...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... 2 I bilan 1.1.- introduction p...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... travail. 1.2. - la période de ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... de 1960. 1.3. - la révolution ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...destin. 5 1.4. - l'indépendance...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...rroriste. 1.6. - une nouvelle g...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...texte de l'indé- •9 pendantisme...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...rètement. 1.7. - une nouvelle l...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ratégique 2.1. - un nouveau dép...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...tratégie. 2.2. - liquidation du...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ailleurs. 2.3. - préparation de...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...e nous aider : - nous faire un ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... d'équipement, -- nous envoyer ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...d'équipement, -- nous envoyer u...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...bonner un ami, - si cela conven...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...

# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ace. Les N.P.D.-istes dissident...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...t que le N.P.D.-isme venait de ...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...e moins qu'une - révolution de ...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...our une élite, - dont 'l'esprit...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...anque d'emploi - pendant que le...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...eté. En effet: - Depuis 1950, l...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ole au Québec; - Ce qui signifi...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...cents en 1963. - En 1961, sur 9...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...% en Abitibi ! - La moyenne ari...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...par l'U.C.C. 2 - Le manque de p...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... tout réglé. 3 - Un troisième f...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...extérieur... 4 - L'obligation p...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... possibilités: - de favoriser l...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ns des autres; - de réaliser un...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...e coopératif); - d'élaborer une...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...consommation); - de créer des v...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ée du travail; - bref, de plani...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ture capitale: - la nécessité d...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... de son temps; - faire particip...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...syndicale (9); - procéder à une...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...poration Sir G.-E. Cartier) afi...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... conflit U.D.A.-A.E. à sa techn...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...l'intervention - quelqu'en soit...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...n soit le mode - des représenta...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... "intellectuel - petit bourgeoi...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...urgeois aliéné - boursier - du ...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...me un écrivain - un auteur - qu...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...in - un auteur - qui ne parvien...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...l était enfant -, la mer, la Se...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ... nous confiait - mais ce n'est ...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ur publication - qu'il donnerai...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...ns plus de 007 - à travers le m...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...avers le monde - de (1) — qu'en...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...omme hypothèse - le premier hér...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...iné un travail - et quel travai...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...RIS/p.m.Notes: - L'équipe du jo...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...it où elle va. - Nous disions, ...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...on publique :1 - Les syndicats ...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ... en Belgique;2 - La C.G.T. les ...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...ats français;3 - Les journaux d...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...ays du monde;4 - Et toutes les ...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...Vous n'êtes qu'- une clique de ...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...mplifie. 40 II - la perspective...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...parti pris / j.-m.p....
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...re concurrence -- chacun pour s...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...e concurrence -- chacun pour so...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...DOCUMENT MORIN - L'HEUREUX - CH...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...IN - L'HEUREUX - CHARTRAND PAR ...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ... confrontations---montages cons...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...confrontations---montages const...
# ----------------------------------------
# Source: 163122_1-1964-03.json
# Context: ...onfrontations---montages consta...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ... durer. Il dit - mon cri doit d...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...nce québécoise - Il a écrit - R...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...e - Il a écrit - RUTS - et - OR...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...a écrit - RUTS - et - OR LE CYC...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...it - RUTS - et - OR LE CYCLE DU...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...SANG DURE DONC - Il a commencé ...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...ue en physique - et que — la po...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...emple, ce vers - tympan détampo...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ... temps à venir - Il y a ici un ...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...iciens de jazz - Parler d'une p...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ... hommes atones - québécois. DUG...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...on. Exorcisme. - ce cri est réa...
# ----------------------------------------
# Source: 163122_2-1967-10.json
# Context: ...e la négritude - Ce n'est pas p...
# ----------------------------------------
# ...
# Source: 163122_1-1965-12.json
# Context: ..., s'expliquent - une coordonnée...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...en parle ainsi -, alors qu'ils ...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...euvre parfaite - et bouleversan...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...ns parler de J.-L.G.; dans quel...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ... l'oeil gauche - les corps étra...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...ers, toujours! - et la grand' m...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ... où l'écrivain - qu'il faudra a...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...d'un autre nom - parlera effect...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...ter un "livre" - qu'il faudra a...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...d'un autre nom - aussi attentiv...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...ie "Manifeste" - Ce sera "une l...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ...amais prétendu - ou osé le fair...
# ----------------------------------------
# Source: 163122_1-1965-12.json
# Context: ... osé le faire! - que celui que ...
# ----------------------------------------
# Source: 163122_2-1966-05.json
# Context: ...e $1,000. à $2,-000. inférieurs...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...t favorisée. J.-J. Richard, Gil...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...1. - une saison en ...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ... s'effondre. 2.- bien écrire ma...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...des autres. 3. - je est un autr...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...l'humanité. 4. - l'improvisatio...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...1 - J'appelle éloq...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...ous possède. 2 - Chaque homme e...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...us permettront - bientôt, je l'...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...t, je l'espère - de la résoudre...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...la résoudre. 1 - réformes et ré...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e deux buts: 1.- diffuser les d...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...s militants; 2.- créer au sein ...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ns subjectives - ce qui est, se...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...de procéder. 1 - pour ceux qui ...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e l'assemblée. - un pavoisement...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e à organiser. - l'adresse du s...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...t les sections - Chaque section...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ue Parti Pris. - Chaque mois, l...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...nt professeur. - Au moins une f...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ... les sections. - Chaque section...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ntreprendre. 3 - genre d'action...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...es. Agitation. - distribution d...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...tion de tracts - appui durant l...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ant les grèves - manifestations...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...c. Propagande. - Communiqués au...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...mes du milieu. - écrire des bro...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...es suivants: 1 - La revue est c...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...qui agiront. 3 - expansion du m...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...oncertée C.S.N.-U.C.C. contre l...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...chent: artifice-(lake)-authenti...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...artifice-(lake)-authenticité (n...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...sme étudiant: 1-) L’accès à la ...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...Québec à l’U.G.-E.Q. et 3-) Les...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...’U.G.-E.Q. et 3-) Les liens de ...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ... force à l’U.G.-E.Q. Disons d’a...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...i sont à l’U.G.-E.Q.: ils sont ...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...airement l’U.G.-E.Q., mais leur...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...ale (livre d’A.-P. Lentin sur l...
# ----------------------------------------
# Source: 163122_2-1967-03.json
# Context: ...n Garcia, et J.-L. G., dans DEU...
# ----------------------------------------
# Source: 163122_1-1964-11.json
# Context: 

# ----------------------------------------
# Source: 163122_1-1964-10.json
# Context: ...z sa réponse: "-Oh, non! J'en v...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ... (110,000 : 25,-000) le RIN 2 s...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...s (50,000 : 25,-000) l'U.N. 1 s...
# ----------------------------------------

# %% [markdown]
# **New Types**
#
# Looking through the hyphens other than the ones that we expected, we were able to discover some new examples. We serve a role in the corpus, so we should not change them.
#
# *Dash as punctuation or separator*
# - Used like an em dash or to separate clauses, items, or list elements.
#   Example: `Justice sociale - histoire de vo...`
#   Example: `Place des Arts - pauvre de moi ...`
#
# *Numbered/lettered lists and section markers*
# - Used after numbers or letters to mark sections or list items.
#   Example: `1.1.- introduction`
#   Example: `a - les animateurs`
#
# *Double or triple hyphens*
# - Used for emphasis, as a separator, or to mimic a long dash.
#   Example: `d'équipement, -- nous envoyer ...`
#   Example: `contradiction--- en ce sens...`
#
# *Hyphens in abbreviations or initials*
# - Used between initials, abbreviations, or acronyms.
#   Example: `J.-L. G.`
#   Example: `C.S.N.-F.T.Q.`
#   Example: `P.-E. Trudeau`
#
# *Hyphens in numeric ranges*
# - Used to indicate ranges or as part of numeric formatting.
#   Example: `$5-$10 par mois`
#   Example: `la guerre '39-'45`

# %% [markdown]
# **Edge Cases**
#
# We also found some edge cases that we need to account for.
#
# *Word-break with capital letter*
# - Sometimes a word-break hyphen is followed by a capital letter and then the rest of the word, likely due to OCR or formatting issues.
# - Example:
#   - `rap- P port à Cité Libre`
#
# *Word-breaks with page numbers or bullets*
# - Occasionally, a word-break hyphen is followed by a bullet, page number, or other artifact from the page layout.
# - Example:
#   - `d'appren- • 61 dre`

# %% [markdown]
# Turns out `rap- P port à Cité Libre` is a unique edge case and not an example of a model mistake pattern. Other instances of hyphen and then space and then a capital letter and then space and then some lowercase letters are just lists: `1- A ceux`. We edited the word rapport in the csv directly.

# %%
# Let's load the partipris_v2.csv, which is the same as v1 but with the word "rapport" fixed
# We will override this file after the entire hyphen processing is done
partipris = pd.read_csv('../data/processed/partipris_v2.csv')

# %%
# Let's see if the edge case is fixed
edge_case_count = partipris['text'].str.contains(r'rap- P port à Cité Libre', na=False).sum()
if edge_case_count > 0:
    print(f"Found {edge_case_count} instances of the edge case 'rap- P port à Cité Libre'.")
else:
    print("No instances of the edge case 'rap- P port à Cité Libre' found.")
# Out:
# No instances of the edge case 'rap- P port à Cité Libre' found.

# %% [markdown]
# This Haut-Canada example is like a canary in the mine. It is going to help us keep track of the hyphen removal. It is a good example because we want to fix hyphenation of `Haut- Canada` but we do not want to turn it into `HautCanada`

# %%
# HautCanada vs Haut-Canada
# Let's check how many instances of 'HautCanada' exist
haut_canada_count = partipris['text'].str.contains(r'HautCanada', na=False).sum()
if haut_canada_count > 0:
    print(f"Found {haut_canada_count} instances of 'HautCanada'.")
else:
    print("No instances of 'HautCanada' found.")
# Out:
# No instances of 'HautCanada' found.

# %%
haut_dash_canada_count = partipris['text'].str.contains(r'Haut-Canada', na=False).sum()
if haut_dash_canada_count > 0:
    print(f"Found {haut_dash_canada_count} instances of 'Haut-Canada'.")
else:
    print("No instances of 'Haut-Canada' found.")
# Out:
# Found 5 instances of 'Haut-Canada'.

# %%
haut_dash_space_canada_count = partipris['text'].str.contains(r'Haut- Canada', na=False).sum()
if haut_dash_space_canada_count > 0:
    print(f"Found {haut_dash_space_canada_count} instances of 'Haut- Canada'.")
else:
    print("No instances of 'Haut- Canada' found.")
# Out:
# Found 2 instances of 'Haut- Canada'.

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      698 non-null    object
#  1   author           695 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
#  5   volume_number    593 non-null    object
#  6   issue_number     698 non-null    object
#  7   season_or_month  698 non-null    object
#  8   year             698 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 49.2+ KB

# %% [markdown]
# Was this important enough to fix? Probably not. But it is an example of how one can deal with some edge cases manually. It is ok to just command-F in a csv and edit things :D

# %%
# Let's handle the other edge case: d'appren- • 61 dre
# there are more examples of this: démis- • 27 sionnaires; progres- • 29 siste
# and also s'as- 30. sure; de- 83 venue
# it seem to be the case where the hyphenation breaks the word onto the next page

# Exclude cases where the hyphen is between two numbers (e.g. $5-$10; '39-'45)
# Pattern: letter(s) + hyphen + optional spaces + (non-word or nothing) + optional spaces + 1-3 digits + optional punctuation + optional spaces + letter(s)
pattern = r"[a-zA-ZÀ-ÿ]+-\s*(?:[^\w\s]+)?\s*\d{1,3}[^\w\s]?\s*[a-zA-ZÀ-ÿ]+"

# Count total number of matches across all rows
total_count = partipris['text'].apply(lambda x: len(re.findall(pattern, str(x)))).sum()
print(f"Total number of pattern matches: {total_count}")

# Let's look at the matches
matches = partipris[partipris['text'].str.contains(pattern, na=False, regex=True)]

for idx, row in matches[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, row['text']):
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        print(f"Source: {row['source_file']}")
        print(f"Context: ...{row['text'][start:end]}...")
        print('-'*40)
# Out:
# Total number of pattern matches: 86
# Source: 163122_1-1964-09.json
# Context: ...ne révolution qui pourtant se vou- 8. drait populaire. La seule violence ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ez nous dans le contexte de l'indé- •9 pendantisme dont elle était un approfondi...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...au contraire un progrès et un approfondisse- 12. ment de la lutte qui, en s'inséran...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... politique; lorsque l'on veut pas- 20. ser à l'action, c'est-à-dire réal...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ..., le "combat" ne fut alors qu'ex- • 25 clusivement idéologique pour ne pas dire ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...se interne (cf. l'épisode des démis- • 27 sionnaires), semble de plus en plus somb...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...haines années. La bourgeoisie progres- • 29 siste optera-t-elie ouvertement pou...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...un pays souverain dont elle s'as- 30. sure la domination. Le facteur déc...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...uissance de la gauche affecte égale- 32. ment le mouvement de libération, d...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ne bourgeois. Et, hélas! on n'au- 40. rait pas tout à fait tort. Mais, p...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...stes. Mais de Gauche, jamais. Peut- 42. être ce qui différencie le plus no...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...Chamberland) l'existence, à l'inté- 50. est catholique. L'Eglise et les i...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... à notre liberté de penser, d'appren- • 61 dre, nous ne pouvons le supporter...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... aussi longtemps le quotidien politique- 70. denys arcand ment le plus influent ...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...eurs et de membres des partis Libé- 39 ral et Union Nationale qui votent...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: 

# ----------------------------------------
# Source: 163122_1-1964-10.json
# Context: ... lende-mains de la chute d'un DC-8 près de Montréal, CBFT a sorti de ...
# ----------------------------------------

# %% [markdown]
# 86 instances of this kind of word break that goes over page boundaries. Not bad!
#
# Let's fix them: d'appren- • 61 dre → d'apprendre, s'as- 30. sure → s'assure

# %%
# Pattern from above to clean up the edge case hyphenation
pattern = r"([a-zA-ZÀ-ÿ]+)-\s*(?:[^\w\s]+)?\s*\d{1,3}[^\w\s]?\s*([a-zA-ZÀ-ÿ]+)"

def clean_edge_case_hyphens(text):
    # Join the split word fragments, removing the page/bullet artifacts
    return re.sub(pattern, r"\1\2", text)

# Apply cleaning to the entire column
partipris['text'] = partipris['text'].apply(clean_edge_case_hyphens)

# %%
# Let's see if we were able to fix this

pattern = r"[a-zA-ZÀ-ÿ]+-\s*(?:[^\w\s]+)?\s*\d{1,3}[^\w\s]?\s*[a-zA-ZÀ-ÿ]+"

# Count total number of matches across all rows
total_count = partipris['text'].apply(lambda x: len(re.findall(pattern, str(x)))).sum()
print(f"Total number of pattern matches: {total_count}")
# Out:
# Total number of pattern matches: 0

# %% [markdown]
# Now, let's move onto the word-break corrections

# %%
# The most simple way to do this would be with a word- word pattern

pattern = r'(\w+)- (\w+)' 

matches = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, str(row['text'])):
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        matches.append((row['source_file'], row['text'][start:end]))

print(f"Found {len(matches)} instances of 'word- word' pattern.")
for source, context in matches:
    print(f"Source: {source}")
    print(f"Context: ...{context}...")
    print('-'*40)
# Out:
# Found 6162 instances of 'word- word' pattern.
# Source: 163122_1-1964-09.json
# Context: ...N. Le contexte politique de l'heu- re, où la question qui faisait l...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... en fait, nous ne disions pas claire- ment ce que serait cette révolutio...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...le jour. En somme le front se dé- plaçait, une nouvelle lutte s'engagea...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...uttes sociales commençaient à infor- mer la lutte de libération nation...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...e se radicaliser et de donner nais- sance au vrai combat, à la lutte ré...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... en éclairer l'origine et les struc- tures, et tentent d'en dévoiler les...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...nces pour ceux qui se veulent révolu- tionnaires; car la révolution, maintenan...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...urgeoisie libérale canadienne-fran- çaise du XIXe siècle, qui agissait ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...hauvin, le cléricalisme et le patro- nage soutenaient une manière de fé...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ..., l'idéologie de l'opposition pro- gressiste. Cette alliance de forces nou...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...tait dans ses rangs autant de tradition- nalistes attardés et patroneux que de ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...cette bourgeoisie chercha à s'affer- mir, donc à stabiliser le mouveme...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...atiste et l'autre socialiste, mi- litaient depuis un certain temps. L'un...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... l'autre avaient des contenus idéolo- giques, politiques et sociaux assez ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...rigines et les opinions assez diver- ses de ses membres rendaient inév...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...nous; et, en 63-64, ce fut le déblo- cage; l'O.J.C. et les SSJB, après ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ar certains de ses ministres, vien- nent de se prononcer en faveur de ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...e séparatiste, sous une forme atté- nuée, savamment graduée, respectab...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... est peu à peu assumée par la bour- geoisie. La nouvelle bourgeoisie, eng...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ces besoins conduisent vers l'in- dépendance. Ce n'est pas une idéologie, ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...rti Libéral alliée aux autres repré- sentants de la bourgeoisie nationale; ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... un régime de prétendue unité na- tionale... Cela n'est pas pour demain...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: 

# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...tin); 2- lutte parlementaire; 3- lutte armée ? 2.3 situation révolut...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e faudrait pas perdre de vue: 1- à Alger, la répression français...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...s les six mois le réseau FLN; 2- la Résistance française, tout en...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ables faute de militants et d'organisation- d'utiliser complètement. Et nou...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...est prévue pour octobre 1965. 2- COURS PRATIQUE (comment faire). Ces...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ... des manifestation; etc. etc. 3- COURS THÉORIQUE (pourquoi faire) Ce...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...1- changement de nom Les membres du mouveme...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...sur le plan de l'appellation. 2- Le nom parti pris ne signifie ri...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...a base chez les travailleurs. 2- catégories de membre L'assemblée général...
# ----------------------------------------
# Source: 163122_1-1964-11.json
# Context: ...maîtres et larbins y compris. 2- politique rédactionnelle Nous aimerions...
# ----------------------------------------
# Source: 163122_2-1967-01.json
# Context: ...isse délibérément les niveaux infra- et super-fonctionnels pour se co...
# ----------------------------------------
# Source: 163122_2-1967-01.json
# Context: ...La Renaude R- folle et le gastronome Shampoo sont...
# ----------------------------------------
# Source: 163122_2-1966-03.json
# Context: ...core très extensible en 1848."II- la théorie marxiste des crisesLe...
# ----------------------------------------
# Source: 163122_1-1964-10.json
# Context: ...ndent fonder leur politique d'in- formation sur un seul critère : l'objec...
# ----------------------------------------

# %% [markdown]
# There are 6162 instances of this pattern but not all are what we want. We should look into this further to avoid hits like: `4- Le Devoir`, `1- Quand`, `3- Nous` or 'Haut- Canada'
#
# Let's look at the number pattern first.

# %%
# number pattern

pattern = r'(\d+)- (\w+)' 

matches = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, str(row['text'])):
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        matches.append((row['source_file'], row['text'][start:end]))

print(f"Found {len(matches)} instances of 'word- word' pattern.")
for source, context in matches:
    print(f"Source: {source}")
    print(f"Context: ...{context}...")
    print('-'*40)
# Out:
# Found 104 instances of 'word- word' pattern.
# Source: 163122_1-1964-09.json
# Context: ...ons. 46 les buts à long terme 1- Je voudrais d'abord répondre à c...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...artis de masse yvon hussereau 1- les partis traditionnels quelques...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...n. leader OFFICEUX qui exerce 2- organisation par cellules les caractéristi...
# ----------------------------------------
# Source: 163122_1-1965-04.json
# Context: ...estera les mines de baloney". 3- La Presse, 17 fév. 1965. 4- Le D...
# ----------------------------------------
# Source: 163122_1-1965-04.json
# Context: .... 3- La Presse, 17 fév. 1965. 4- Le Devoir, 2 mars 1965. mario du...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...oin du premier que du second. 1- Quand une certaine gauche consentir...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...équivaloir à extrême sottise. 2- Moins définir que travailler. Reste...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...e son pays, et de son milieu. 3- Nous savons ce que nous voulons. M...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...us éviter plus d'une naïveté. 4- Il s'agit de savoir si l'on peut...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...t son caractère d'orthodoxie. 5- Il y a des groupes, des projets,...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...availler avec les premiers... 6- Pour quelqu'un de tendance indépen...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...f et la réalité, avec le MSA. 7- Sans en ressortir aussitôt ......
# ----------------------------------------
# Source: 163122_1-1964-05.json
# Context: ... la consolidation des fermes. 2- préparation de la population Le comité se...
# ----------------------------------------
# Source: 163122_1-1964-05.json
# Context: ...les méthodes de comptabilité. 3- début de consolidation des fermes D...
# ----------------------------------------
# Source: 163122_1-1964-05.json
# Context: ... consolidé leur exploitation. 4- le plan d'aménagement de la paro...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ... auxquels nous sommes arrivés.2- aspect théorique des classes sociale...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...cal Statistics of the U.S.A., 1789- 1939; Statistical Abstracts, U.S.A...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...mes de levesque DE CONSCIENCE 1- A ceux qui à la guerre Torturen...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...nt Dieu Et devant les hommes. 2- L'Eglise a trahi De n'avoir jam...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ... la guerre. L'Eglise a trahi. 3- Où est la civilisation Quand le ...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...autre Que de détruire la vie. 5- La bêtise C'est le malheur. Part...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...la mort Et la fin de l'homme. 6- La guerre n'est pas un métier, Q...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...7- Il n'y a point d'honneur A tenir...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...a trois hypothèses possibles. 1- C'est la faute de l'élite cléri...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...tagerait cette hypothèse ?... 2- C'est la faute des Anglais. Un ...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...si, je ne m'y attarderai pas. 3- La troisième hypothèse ne fait p...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...avorisant l'assimilation(14): 1- La ressemblance entre les struct...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...es mentales des deux peuples; 2- l'instruction rendant plus faci...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...dividus à un groupe étranger; 3- une fréquence élevée des communic...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...tions entre les deux peuples; 4- l'importance des récompenses ma...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...x candidats à l'assimilation; 5- la concordance des valeurs du pe...
# ----------------------------------------
# Source: 163122_2-1966-09.json
# Context: ...tes par le peuple dominateur; 6- les symboles nationaux du peuple ...
# ----------------------------------------
# Source: 163122_1-1965-02.json
# Context: ...erminants sont probablement : 1- Le bas niveau de l'éducation en ...
# ----------------------------------------
# Source: 163122_1-1964-06.json
# Context: ...ial de l'homopoliticus à nous 1- Il y a deux ans déjà, Pierre Lef...
# ----------------------------------------
# Source: 163122_1-1964-06.json
# Context: ...e être un Pauwells québécois. 2- Cette prise de conscience nationale...
# ----------------------------------------
# Source: 163122_1-1964-06.json
# Context: ...familles, surtout nombreuses. 4- surveiller l'entrée au Canada de tout él...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...ions et de soumissions. NOTES 1- Cette méfiance des effets de la rév...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...iante, éd. Cité libre, p. 33. 2- Rumilly, Robert, Quinze années de réa...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...français, 111 (1957): 31-117. 5- Memmi, Albert, Portrait du colonisé...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...Buchet/ Chastel, 1957, p. 26. 6- Rumilly, Robert, Quinze années de réa...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...s. Les faits parlent, p. 233. 7- Fortin, Gérard, "La famille canadien...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: .... Le Devoir, le 22 juin 1963. 8- Statistiques pour le mois de mai 1963. Sta...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...contradictions fondamentales: 1- le Québec est dominé par l'impér...
# ----------------------------------------
# Source: 163122_1-1963-10.json
# Context: ...mpérialisme canado-américain; 2- notre société est caractérisée par ...
# ----------------------------------------
# Source: 163122_2-1968-04.json
# Context: ...o, Cleveland et Philadelphie. 1965- Le patriote Gilles Legault, vict...
# ----------------------------------------
# Source: 163122_1-1965-03.json
# Context: ..., c'est-à-dire les expliciter.3- les médiatiser dans la mesure du ...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...mination ou d'intolé- rance. "2- Le Mouvement entend accueillir e...
# ----------------------------------------
# Source: 163122_1-1965-10.json
# Context:

# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...mmes et ceux que nous serons. 3- Tout cela, le dicible et l'indicib...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...anie, d'une kyrielle de cris. 4- On trouve chez Roland Barthes (L...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ... pour que flambe leur prison. 5- L'écrivain, tout révolutionnair...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ... se coiffe pas d'une auréole. 6- La fameuse distanciation, chez B...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...te, c'est-à-dire paroissiale. 7- Lors d'une conférence prononcée à ...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...prise sur le plan littéraire. 8- Un roman pèse-t-il bien lourd à ...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ...re ensemble: tous des hommes. 9- L'écrivain qui a honte d'écrire...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...tapes ne devraient pas être : 1- organisation d'un mouvement légal par agit...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...n d'un mouvement clandestin); 2- lutte parlementaire; 3- lutte armée...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...tin); 2- lutte parlementaire; 3- lutte armée ? 2.3 situation révolut...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e faudrait pas perdre de vue: 1- à Alger, la répression français...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...s les six mois le réseau FLN; 2- la Résistance française, tout en...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...est prévue pour octobre 1965. 2- COURS PRATIQUE (comment faire). Ces...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ... des manifestation; etc. etc. 3- COURS THÉORIQUE (pourquoi faire) Ce...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...1- changement de nom Les membres du mouveme...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...sur le plan de l'appellation. 2- Le nom parti pris ne signifie ri...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...a base chez les travailleurs. 2- catégories de membre L'assemblée général...
# ----------------------------------------
# Source: 163122_1-1964-11.json
# Context: ...maîtres et larbins y compris. 2- politique rédactionnelle Nous aimerions...
# ----------------------------------------

# %% [markdown]
# 104 instances! We should make sure not to include these in our edits

# %% [markdown]
# Let's look at the word- Word, for cases like Haut- Canada without the digits

# %%
# Pattern: lowercase or capitalized word, hyphen, space, Capitalized word
pattern = r'\b(?!\d+\b)\w+- [A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]\w+'

matches = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, str(row['text'])):
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        matches.append((row['source_file'], row['text'][start:end]))

print(f"Found {len(matches)} instances of 'word- Word' pattern.")
for source, context in matches:  # print for review
    print(f"Source: {source}")
    print(f"Context: ...{context}...")
    print('-'*40)
# Out:
# Found 68 instances of 'word- Word' pattern.
# Source: 163122_1-1964-09.json
# Context: ... plusieurs journalistes de LA PRES- SE, aujourd'hui menacés dans leu...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... et de faire du conflit de LA PRES- SE l'importante affaire politiqu...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...s of Lightnin' Hopkins (Verve Folk- FV/FVS-9000). Hootin' the blues ...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...ément cela: ORGANISATION DE L'AVANT- GARDE EN VUE DE CREER LE PARTI REVO...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...EER LE PARTI REVOLUTIONNAIRE, INSTRU- MENT DE LA PRISE DU POUVOIR. Nous ...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...geoisie, à ORGANISER LE PARTI REVOLUTION- NAIRE. A nos militants, nous demand...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...in LE QUEBEC AUX TRAVAILLEURS QUEBE- COIS. Le Mouvement de Libération P...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...e manifeste 64-65 de la revue Parti- Pris, "c'est qu'il est sous-étudié...
# ----------------------------------------
# Source: 163122_1-1965-08.json
# Context: ...orique des classes sociales 2.I- Existence et définition des clas- ses s...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...lon trouvera à son arrivée en Nouvelle- France et qu'il transformera en un p...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...nts qui se dispersent dans le Haut- Canada et les Etats-Unis. De 1829 à ...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...es commerces y surgissent. La Basse- Ville devient le comptoir d'échange...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...e St-Louis jusqu'à Sillery et Ste- Foy et même sur les battures de B...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...e encore; il devient, avec la Basse- Ville – et bien plus qu'elle à mesu...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...rent en communication avec le Haut- Canada et, par les Grands Lacs, avec...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...tendant sur les deux rives du St- Laurent et comprenant 52 municipalité...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: .... Il faut bien dire que si le Vieux- Québec est d'une beauté quasi-légend...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...quartier St-Jean-Baptiste. La Grande- Allée, à proximité des Plaines d'Ab...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...e la ville, la papeterie de l'Anglo- Canadian Pulp and Paper Co. (une en- t...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...enu annuel moyen par ménage à Ste- Foy était de $9,466., Alors que c...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...re des cercles féminins de la Haute- Ville à Québec et celle des mêmes c...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...sez profondément modifiée. La Basse- Ville (partie basse du quartier Cha...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...t en direction du quartier St-Jean- Baptiste et de la partie nord du quart...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...ue par l'isolement relatif de St- Sauveur, entouré de quartiers commer-...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...dant la bénédiction d'Aujourd'hui- Québec. Pendant longtemps, nous avon...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ...ague). Accepter l'Association Québec- Canada, comme cadre politique à l'ép...
# ----------------------------------------
# Source: 163122_1-1965-05.json
# Context: ..., Gérald Godin, Pierre Maheu, Jean- Marc Piotte. Ce comité provisoire ...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ... des avalés" ou à Patricia et Jean- Baptiste. Je trouve ici opportun de ci...
# ----------------------------------------
# Source: 163122_2-1968-05.json
# Context: ...t- tre", un film d'un dénommé Jean- Pierre Lefebvre, cinéaste québé- coi...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...e de l'oeuvre; faire de Saint-Denys- Garneau un mystique tourmenté par la ...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...s il eût pu recourir alors à "Très- Haut", à "Tout-Puissant", à l'Etre...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...EUX DE PELLETIER, TOUT CE QUE FE- RONT LES SEPARATISTES SERA MAU- VA...
# ----------------------------------------
# Source: 163122_1-1963-11.json
# Context: ...E- RONT LES SEPARATISTES SERA MAU- VAIS PARCE QUE CE SONT EUX QUI LE ...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...nne n'est plus tipop que Jean Ethier- Blais. C'est dire que les termes ne...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...de- cessor into an art form." Mc- Luhan écrivant ces lignes décrit un...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...lâche. Mais Lefebvre tournant Jean- Baptiste, et Lefebvre jouant Jean- Bap...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ... Baptiste, et Lefebvre jouant Jean- Baptiste, c'est autre chose. Il n'est ...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...e. Comme si Lefebvre assumait Jean- Faptiste, tout en étant désespéré de n...
# ----------------------------------------
# Source: 163122_2-1968-03.json
# Context: ...rs n'est pas encore possible. Jean- Baptiste ne peut pas avoir de deve- ni...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...crit à l'intention de l'UNION RATIONA- LISTE française. Il paraîtra, m'a-t...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...ésidents les savants Frédéric Joliot- Gurie et Paul Langevin. Soyons mode...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...qu'ils ont jurés au roi de la Grande- Bretagne, dans l'obéissance ponctuelle...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...lendissant soleil de la Saint-Jean- Baptiste, son ancienne`et incommensura...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...-structure littéraire du type Robbe- Grillet. Ainsi l'astructuration équiv...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...rs." Il est tombé et il s'est endor- Cela les hypnotisa; ils se courbèr...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...e l'eau salée, en aval du Lac Saint- Pierre; c'était un tout petit pays, ...
# ----------------------------------------
# Source: 163122_1-1964-01.json
# Context: ...sible que dans les parages de Terre- Neuve, parages fréquentés depuis lo...
# ----------------------------------------
# Source: 163122_1-1965-10.json
# Context: ...t ignoré pour que l'imposture Trudeau- Pelletier - Marchand passe, Jean-Jules ...
# ----------------------------------------
# Source: 163122_1-1965-10.json
# Context: ...u mouvement de masse dans son en- Chansonniers du Québec sur disques MADRIGA...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...côté idéologique des idées de Mc- Luhan qui fascine les artistes dont...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...sicales de J. Vallerand et de Papineau- Couture, la bourgeoisie cléricale mar...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...iers sont ici remplacées par "Echo- Vedette", Télé-Radio Monde et les aut...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...ies et des théâtres de poche (Apprentis- Sorciers. Egrégore...) et des Ciné- ma...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...on L'incendie des villages de Saint- Eustache et de Saint-Benoît en décem- ...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...han? Dès le début du combat à St- Denis, ils se sont enfuis à St-Hyac...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...arent des plans d'invasion du Bas- Canada, avec la collaboration de re-...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...bles ont été fomentés dans le Haut- Canada dont la population était "ra-...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...7-38. On a souvent dit que la Nouvelle- France, au moment de la Conquête, ét...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...- ses grandement. En fait, la Nouvelle- France était une colonie agricole et...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...dans le Bas-Canada ni dans le Haut- Canada non plus. Dès après la Conquê...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...ent aux groupes d'intérêts du Bas- Canada, nous en avons reconnu trois....
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ... les courants idéologiques du Bas- Canada doivent beaucoup à ceux de la...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...construction de canaux sur le Saint- Laurent pour le commerce et, finale- ...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ... des idées en 1837-38 dans le Bas- Canada se sont battus parce qu'ils 9...
# ----------------------------------------
# Source: 163122_2-1967-09.json
# Context: ...- Aquin - Ducharme - Blais... IX- Une activité proprement révolutio...
# ----------------------------------------
# Source: 163122_2-1967-05.json
# Context: ...de la série "A History of the English- Speaking People", Toronto, McClelland ...
# ----------------------------------------
# Source: 163122_1-1963-12.json
# Context: ...ROPE QUE DE PARLER D'ECRIVAIN CANADIEN- FRANÇAIS. LE CANADIEN FRANÇAIS N'EXIST...
# ----------------------------------------
# Source: 163122_1-1965-01.json
# Context: ... avec autant de contention qu'Ethier- Blais ou Paul Toupin, c'est une faç...
# ----------------------------------------

# %% [markdown]
# 68 instances! Some are like this: `INSTRU- MENT`, where is it a word that was split by hyphenation and others are like this `Saint- Laurent`, a word that was originally spelt with a hyphen but for some reason, it was split.
#
# Now this becomes more generalizable. Let's incorporate what we already know about word breaks.
# - If both sides of the hyphen are ALL UPPERCASE or all lowercase, join them (likely a split word).
# - If the left is Titlecase or uppercase and the right is Titlecase (e.g., Haut- Canada), keep the hyphen and remove the space (→ Haut-Canada).

# %%
import re

# Patterns from your fix_hyphen_splits function
pattern_allcaps = r'\b([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]+)- ([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]+)\b'
pattern_alllower = r'\b([a-zà-ÿ]+)- ([a-zà-ÿ]+)\b'
pattern_titlecase = r'\b(?!\d+\b)([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ][a-zà-ÿ]+)- ([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ][a-zà-ÿ]+)\b'

def count_hyphen_cases(texts):
    count = 0
    for text in texts:
        count += len(re.findall(pattern_allcaps, str(text)))
        count += len(re.findall(pattern_alllower, str(text)))
        count += len(re.findall(pattern_titlecase, str(text)))
    return count

# BEFORE cleaning
before_count = count_hyphen_cases(partipris['text'])
print(f"Before cleaning: {before_count} cases matching fix_hyphen_splits patterns")
# Out:
# Before cleaning: 5638 cases matching fix_hyphen_splits patterns

# %%
def fix_hyphen_splits(text):
    # 1. Join split words: ALLCAPS- ALLCAPS or all lowercase, but not digit- word
    text = re.sub(r'\b([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]+)- ([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]+)\b', r'\1\2', text)
    text = re.sub(r'\b([a-zà-ÿ]+)- ([a-zà-ÿ]+)\b', r'\1\2', text)
    # 2. Remove space after hyphen for compounds: Title- Case → Title-Case, but not digit- Word
    text = re.sub(r'\b(?!\d+\b)([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ][a-zà-ÿ]+)- ([A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ][a-zà-ÿ]+)\b', r'\1-\2', text)
    return text

partipris['text'] = partipris['text'].apply(fix_hyphen_splits)

# %%
after_count = count_hyphen_cases(partipris['text'])
print(f"After cleaning: {after_count} cases matching fix_hyphen_splits patterns")
# Out:
# After cleaning: 0 cases matching fix_hyphen_splits patterns

# %% [markdown]
# **Whitespace**
#
# The next problem that we had initially observed in the text extraction phase was cases where word that were not supposed to be joined, were joined, like:
#
# - des amours **étrangèresJe** te reconnais
# - des **motsTu** es beau
# - pierre **maheuNote:** la plupart
#
# We could describe them as words where a lowercase letter is followed by an upper case letter without whitespace in between. But there are also real examples of this, most notably names like *McGill* or *McLuhan*.
#
# Let's see what the situation is:

# %%
# Find places where a lowercase letter is immediately followed by an uppercase letter (possible missing space)
import re

boundary_pattern = r'[a-zà-ÿ][A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]'

all_suspect_matches = []
rows_with_suspect = set()

for idx, row in partipris[['source_file', 'text']].iterrows():
    found_in_row = False
    for m in re.finditer(boundary_pattern, str(row['text'])):
        # Get a window for context
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        all_suspect_matches.append((row['source_file'], row['text'][start:end]))
        found_in_row = True
    if found_in_row:
        rows_with_suspect.add(idx)

print(f"Total suspect boundaries: {len(all_suspect_matches)}")
print(f"Rows with possible missing whitespace between words: {len(rows_with_suspect)}")

# Print first 10 examples
for example in all_suspect_matches[:10]:
    print(f"Source: {example[0]}")
    print(f"Context: ...{example[1]}...")
    print('-'*40)
# Out:
# Total suspect boundaries: 352
# Rows with possible missing whitespace between words: 126
# Source: 163122_2-1966-02.json
# Context: ...ques et de luttes entre des facRussie, avant 1917, des cellule...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...alker, Muddy Waters, Brownie McGhee, Sonny Terry, etc...) Parm...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...dit: je croyais que c'était MacKenzie King, le premier ministr...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...e informés de l'existence de McLuhan? Il est vrai que dans la ...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...la traduction en français de McLuhan. Sinon, il faudra faire a...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...es... A moins qu'on confonde McLuhan, avec son "délire d'inter...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...ïm Kattan interroge Marshall McLuhan, directeur du "Center for...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ... Bitsch) et MOSAIQUE (Norman McLaren). Michel Cournot, dans un...
# ----------------------------------------
# Source: 163122_1-1965-04.json
# Context: ...citoyens, le cas célèbre de MacLane, éviscéré, démembré, le ra...
# ----------------------------------------
# Source: 163122_1-1965-06.json
# Context: ...tants. A l'angle des rues SaintChristophe et Demontigny, un po...
# ----------------------------------------

# %%
# Of the 352 words with possible missing whitespace, let's see how many are unique
# This pattern captures the full merged word: last lowercase letters + first uppercase + following lowercase letters
import collections

boundary_pattern = r'[a-zà-ÿ][A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]'

def expand_to_word(text, match_start, match_end):
    # Expand left
    left = match_start
    while left > 0 and text[left-1].isalnum():
        left -= 1
    # Expand right
    right = match_end
    while right < len(text) and text[right].isalnum():
        right += 1
    return text[left:right]

all_expanded_merged_words = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    text = str(row['text'])
    for m in re.finditer(boundary_pattern, text):
        merged_word = expand_to_word(text, m.start(), m.end())
        all_expanded_merged_words.append(merged_word)

counter = collections.Counter(all_expanded_merged_words)
print(f"Unique merged words: {len(counter)}")
print("Most frequent merged words:")
for word, count in counter.most_common(20):
    print(f"{word}: {count}")
# Out:
# Unique merged words: 273
# Most frequent merged words:
# McGill: 28
# McLuhan: 14
# LaDurantaye: 7
# MacLean: 6
# McNamara: 5
# DesRochers: 4
# McGregor: 3
# McCoy: 3
# McCarthy: 3
# MacWilliams: 3
# TvB: 3
# McGhee: 2
# McLaren: 2
# LeMoyne: 2
# McLean: 2
# DuBellay: 2
# McGance: 2
# littéraireL: 2
# espritAux: 2
# DuFour: 2

# %% [markdown]
# A lot of these begin with Mc, Mac, Le, La, Du, Des. We know that these are real words. Let's create a pattern that does not take them into account.

# %%
boundary_pattern = r'[a-zà-ÿ][A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]'

# List of prefixes to ignore
prefixes = ('Mc', 'Mac', 'Le', 'La', 'Du', 'Des')

def expand_to_word(text, match_start, match_end):
    left = match_start
    while left > 0 and text[left-1].isalnum():
        left -= 1
    right = match_end
    while right < len(text) and text[right].isalnum():
        right += 1
    return text[left:right]

all_expanded_merged_words = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    text = str(row['text'])
    for m in re.finditer(boundary_pattern, text):
        merged_word = expand_to_word(text, m.start(), m.end())
        # Only add if it does NOT start with any of the prefixes
        if not merged_word.startswith(prefixes):
            all_expanded_merged_words.append(merged_word)

counter = collections.Counter(all_expanded_merged_words)
print(f"Unique merged words (excluding Mc, Mac, Le, La, Du, Des): {len(counter)}")
print("Most frequent merged words (filtered):")
for word, count in counter.most_common(30):
    print(f"{word}: {count}")
# Out:
# Unique merged words (excluding Mc, Mac, Le, La, Du, Des): 238
# Most frequent merged words (filtered):
# TvB: 3
# littéraireL: 2
# espritAux: 2
# facRussie: 1
# SaintChristophe: 1
# LéviStrauss: 1
# EtatsUnis: 1
# SainteCatherine: 1
# maheuNote: 1
# bonheurMontréal: 1
# commUlysses: 1
# motsDIT: 1
# RadioCanada: 1
# MountRoyal: 1
# NouveauBrunswick: 1
# extérieurJ: 1
# révolutionLa: 1
# libérationJusqu: 1
# socialeNous: 1
# révolutionUne: 1
# xénophobieHubert: 1
# inventionSi: 1
# auteurL: 1
# oeuvreUn: 1
# constelléPorte: 1
# désoléEt: 1
# saisChaque: 1
# sablierGaston: 1
# EhrembourgJe: 1
# encoreIls: 1

# %% [markdown]
# We got rid of 40 unique words and they were the most frequent ones. Great! Now let's look at the rest.
#
# TvB is a term and we should keep it aside as well.
#
# We see here some cases, like EtatsUnis which should have been Etats-Unis. But once we add a space between these, it will be fine for our purposes.

# %%
boundary_pattern = r'[a-zà-ÿ][A-ZÉÈÊÎÏÔÛÙÇÀÂÄÖÜ]'

# List of prefixes and protected terms to ignore
prefixes = ('Mc', 'Mac', 'Le', 'La', 'Du', 'Des', 'TvB')

def expand_to_word(text, match_start, match_end):
    left = match_start
    while left > 0 and text[left-1].isalnum():
        left -= 1
    right = match_end
    while right < len(text) and text[right].isalnum():
        right += 1
    return text[left:right]

def split_merged_words(text):
    # Find all merged words not starting with protected prefixes
    matches = []
    for m in re.finditer(boundary_pattern, text):
        merged_word = expand_to_word(text, m.start(), m.end())
        if not merged_word.startswith(prefixes):
            matches.append((m.start(), m.end()))
    # Replace from end to start to avoid messing up indices
    new_text = text
    offset = 0
    for start, end in matches:
        insert_at = start + 1 + offset  # after the lowercase letter
        new_text = new_text[:insert_at] + ' ' + new_text[insert_at:]
        offset += 1
    return new_text

# Apply the splitting to the text column
partipris['text'] = partipris['text'].apply(split_merged_words)

# %%
# Let's test how we did. Do TvB and littéraireL appear now?
tvb_count = partipris['text'].str.contains(r'\bTvB\b', na=False).sum()
if tvb_count > 0:
    print(f"Found {tvb_count} instances of 'TvB'.")
else:
    print("No instances of 'TvB' found.")

litteraireL_count = partipris['text'].str.contains(r'\blittéraireL\b', na=False).sum()
if litteraireL_count > 0:
    print(f"Found {litteraireL_count} instances of 'littéraireL'.")
else:
    print("No instances of 'littéraireL' found.")
# Out:
# Found 1 instances of 'TvB'.
# No instances of 'littéraireL' found.

# %% [markdown]
# Perfect! We have successfully addressed the whitespace issue. Let's save the cleaned partipris

# %%
# save after cleaning
partipris.to_csv('../data/processed/partipris_v3.csv', index=False)

# %% [markdown]
# ### Page Numbers in Text

# %% [markdown]
# The next step in our preprocessing step is finding and removing the page numbers.
#
# Initially, when we were doing the text extraction, asking the model to include page numbers for each article was also helping the model keep the page numbers off the main text body. This was however not always successful. In fact, the model was also not very successful in assigning page number accurately. It often mixed up the page numbers on the page with the page numbers of the PDF We will discard the page number column later.

# %%
partipris = pd.read_csv('../data/processed/partipris_v3.csv')

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      698 non-null    object
#  1   author           695 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
#  5   volume_number    593 non-null    object
#  6   issue_number     698 non-null    object
#  7   season_or_month  698 non-null    object
#  8   year             698 non-null    int64
# dtypes: int64(1), object(8)
# memory usage: 49.2+ KB

# %%
import re

pattern = r'\s\d{1,3}\s'

number_examples = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, str(row['text'])):
        # Get a window for context
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        context = row['text'][start:end]
        number_examples.append((row['source_file'], context))

print(len(number_examples))

# Print first 10 examples
for example in number_examples:
    print(f"Source: {example[0]}")
    print(f"Context: ...{example[1]}...")
    print('-'*40)
# Out:
# 1928
# Source: 163122_1-1964-09.json
# Context: ...ebvre et N. Guterman, p. 177.) 2 I bilan 1.1.- introduction par...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...lus sérieuse de ces tentatives 3 fut celle d'une importante fra...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...endance comme vers son destin. 5 1.4. - l'indépendance tranquil...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... de l'indépendance mis à part, 7 le programme de RIN dépasse à ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...n ou yankee. De l'autre, les • 11 classes populaires de plus en ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...outumiers; sous son emprise la 13 petite entreprise familiale te...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...miques, démographiques, etc. • 15 du pays est un préalable à tou...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...s et compte maintenant plus de 800 abonnés. Plusieurs centaines d...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...e l'indépendantisme des années 60 n'a presque rien à voir, surto...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...er, il faut compter celuilà. • 21 Nous entendions, il n'y a pas ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... de responsabilité politique • 23 ne s'imposera vraiment qu'une ...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...înèrent l'éclatement du R.I.N. 24 * indépendantistes se donnaien...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...e (F.R.I.). Enfin le printemps 64 voit naître la revue "Socialis...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...: résoudre, entre patrons et • 31 ouvriers, des conflits qui ris...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: 

# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ..., le parti gaulliste, recevait 212 sièges avec un même pourcentag...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...ste ne se voyait attribuer que 10 sièges. Aux élections suivante...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...ti communiste occupait quelque 80 siè-ges à l'Assemblée national...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...7.4 % des votes 57.5 39.2 38.2 51 50.2 51.5 Parti libéral 1936 1...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ... des sièges 15.6 81.4 40.3 8.7 25 21.5 % des votes 41.8 54.2 40 ...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ... 25 21.5 % des votes 41.8 54.2 40 36.5 45.8 44.8 On le voit il e...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...ent dans le-quel se retrouvent 4 ou 5 députés, sans expérience ...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...ans le-quel se retrouvent 4 ou 5 députés, sans expérience d'un ...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...tiples tactiques illicites que 300 ans de "tripotage électoral" a...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...r que dans un comté comprenant 50 polls, il faut environ 120 per...
# ----------------------------------------
# Source: 163122_2-1966-02.json
# Context: ...nant 50 polls, il faut environ 120 personnes qui s'occuperont act...
# ----------------------------------------

# %% [markdown]
# Most of the 1928 examples are actual numbers. But some of them are page numbers: `• 91` or `• 101`. This is very similar to the examples where hyphenation was going over the page break. We can refine our regex and remove the dotted numbers.

# %%
# dotted page number pattern
pattern = r'•\s\d{1,3}'

bullet_number_examples = []
for idx, row in partipris[['source_file', 'text']].iterrows():
    for m in re.finditer(pattern, str(row['text'])):
        start = max(0, m.start()-30)
        end = min(len(row['text']), m.end()+30)
        context = row['text'][start:end]
        bullet_number_examples.append((row['source_file'], context))

print(f"Total matches: {len(bullet_number_examples)}")
for example in bullet_number_examples[:10]:
    print(f"Source: {example[0]}")
    print(f"Context: ...{example[1]}...")
    print('-'*40)
# Out:
# Total matches: 44
# Source: 163122_1-1964-09.json
# Context: ...an ou yankee. De l'autre, les • 11 classes populaires de plus en...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...omiques, démographiques, etc. • 15 du pays est un préalable à to...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...t une vie d'homme. parti pris • 17...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ... fasse sa part. la direction. • 19...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...rer, il faut compter celuilà. • 21 Nous entendions, il n'y a pas...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...t de responsabilité politique • 23 ne s'imposera vraiment qu'une...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...i: résoudre, entre patrons et • 31 ouvriers, des conflits qui ri...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...nés le sont dans l'original). • 35...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...pose: nous avons accordé plus • 39 d'importance aux idées qu'aux...
# ----------------------------------------
# Source: 163122_1-1964-09.json
# Context: ...ient en Dieu : désespérément. • 41 Il faut se rappeler les début...
# ----------------------------------------

# %%
# Let's remove it!

def remove_bullet_page_numbers(text):
    return re.sub(r'•\s\d{1,3}', '', text)

partipris['text'] = partipris['text'].apply(remove_bullet_page_numbers)

# %% [markdown]
# Maybe Gemini was not so bad at not inserting page numbers!
#
# Additionally, we will run named entity recognition later on this corpus, which should allow us to identify dates

# %%
# save after cleaning
partipris.to_csv('../data/processed/partipris_v4.csv', index=False)

# %% [markdown]
# ### Author Names

# %%
partipris = pd.read_csv('../data/processed/partipris_v4.csv')

# %% [markdown]
# The next step in the preprocessing is cleaning up the author names. What awe observed throughout this corpus is that the authors appear once with their fullnames and then if they have other articles in the same issue, they use an abbreviation of their names. For example, pierre maheu becomes p.m.
#
# We can clean this up by creating some kind of a lookup table for each issue.

# %%
# Step 1: Find an example of an abbreviated author name

def is_abbreviation(author):
    """Return True if the author name contains a dot (.)"""
    return '.' in str(author)

# Find the first issue with abbreviated author names
for issue, group in partipris.groupby('source_file'):
    abbrev_rows = group[group['author'].apply(is_abbreviation)]
    if not abbrev_rows.empty:
        print(f"Issue: {issue}")
        print("All author names in this issue:")
        print(group['author'].unique())
        break
# Out:
# Issue: 163122_1-1964-03.json
# All author names in this issue:
# ['Parti Pris / J.-M.P.' 'Pierre Maheu' 'Jacques Berque'
#  'Michel van Schendel' 'Jean-Marc Piotte, Paul Chamberland' 'Roger Nantel'
#  'André Major' 'Paul Chamberland' 'Laurent Girouard' 'Jacques Ferron'
#  'Patrick Straram' 'Gérald Godin']

# %% [markdown]
# Our first example is `163122_1-1965-05.json`
# All author names in this issue are `'M. D.' 'michael draper' 'madeleine richer' 'luc dufresne' 'J.M.', 'parti-pris' 'rené beaudin' 'parti pris'`
#
# Upon closer investigation, we found out that J.M. was intentionally left anonymous in the issue itself, which is even more a reason for why we should do the name-abbreviation matching per issue and not for the whole corpus. There could be a person with J.M. initials elsewhere in the corpus.
#
# Another interesting point is that parti-pris and parti pris appear as authors. It makes sense in this case because there are jointly written articles. We should still make sure to normalize it for counting later, to `parti pris`
#
# Otherwise the M. D. is Michael Draper, so our mapping logic should work!

# %%
# Let's create a list like this per issue where there are initials

# For each issue, collect all abbreviated and full author names
issue_abbrev_map = {}

for issue, group in partipris.groupby('source_file'):
    abbrev_authors = [a for a in group['author'].unique() if is_abbreviation(a)]
    full_authors = [a for a in group['author'].unique() if not is_abbreviation(a)]
    if abbrev_authors:
        issue_abbrev_map[issue] = {
            'abbreviated': abbrev_authors,
            'full_names': full_authors
        }

print(f"Number of issues with abbreviated author names: {len(issue_abbrev_map)}")
# Out:
# Number of issues with abbreviated author names: 18

# %%
issue_abbrev_map.keys()
# Out:
# dict_keys(['163122_1-1964-03.json', '163122_1-1964-09.json', '163122_1-1965-05.json', '163122_1-1965-06.json', '163122_1-1965-10.json', '163122_1-1965-12.json', '163122_2-1966-01.json', '163122_2-1966-02.json', '163122_2-1966-04.json', '163122_2-1966-11.json', '163122_2-1967-01.json', '163122_2-1967-03.json', '163122_2-1967-05.json', '163122_2-1967-10.json', '163122_2-1968-01.json', '163122_2-1968-02.json', '163122_2-1968-03.json', '163122_2-1968-05.json'])

# %%
issue_abbrev_map['163122_2-1966-02.json']
# Out:
# {'abbreviated': ['g. g.',
#   'P.',
#   'j. d.',
#   'm. g...',
#   'p. s',
#   'p. s.',
#   'j. f.',
#   'p.m.'],
#  'full_names': ['yvon hussereau',
#   'jean racine',
#   'jacques trudel',
#   'gérald godin',
#   'paul chamberland',
#   'michel euvrard',
#   'patrick straram',
#   nan,
#   'robert boily',
#   'michel guénard']}

# %% [markdown]
# Looking at the 1966-02 issue, we see that the initials p.m. appear but pierre maheu does not. This means that maybe we could do a second pass for the usual suspects.
#
# Let's test a function to do the mapping first

# %%
# Step 2: Mapping initials and names

def initials(name):
    """Extract initials from a name, e.g. 'jean racine' -> 'j. r.'"""
    if not isinstance(name, str) or pd.isna(name):
        return ''
    parts = re.findall(r'\b\w', name.lower())
    return '. '.join(parts) + '.' if parts else ''

def map_abbreviations(abbrev_list, full_names_list):
    mapping = {}
    for abbrev in abbrev_list:
        if not isinstance(abbrev, str) or pd.isna(abbrev):
            mapping[abbrev] = None
            continue
        abbr_initials = ''.join(re.findall(r'[a-z]', abbrev.lower()))
        matches = []
        for full in full_names_list:
            if not isinstance(full, str) or pd.isna(full):
                continue
            full_initials = ''.join(re.findall(r'[a-z]', initials(full)))
            if abbr_initials == full_initials:
                matches.append(full)
        mapping[abbrev] = matches[0] if len(matches) == 1 else None
    return mapping

# Example from '163122_2-1966-02.json'
abbrev_list = ['g. g.', 'P.', 'j. d.', 'm. g...', 'p. s', 'p. s.', 'j. f.', 'p.m.']
full_names_list = ['yvon hussereau', 'jean racine', 'jacques trudel', 'gérald godin', 'paul chamberland', 'michel euvrard', 'patrick straram', None, 'robert boily', 'michel guénard']

abbrev_to_full = map_abbreviations(abbrev_list, full_names_list)
print(abbrev_to_full)
# Out:
# {'g. g.': 'gérald godin', 'P.': None, 'j. d.': None, 'm. g...': 'michel guénard', 'p. s': 'patrick straram', 'p. s.': 'patrick straram', 'j. f.': None, 'p.m.': None}

# %%
# Step 3: Let's create a new author_edited column

import numpy as np

def create_author_edited_column(df):
    # For each issue, build the mapping and apply it
    author_edited = []
    for issue, group in df.groupby('source_file'):
        abbrev_list = [a for a in group['author'].unique() if isinstance(a, str) and '.' in a]
        full_names_list = [a for a in group['author'].unique() if isinstance(a, str) and '.' not in a]
        mapping = map_abbreviations(abbrev_list, full_names_list)
        # Map each author in the group
        for idx, row in group.iterrows():
            author = row['author']
            if pd.isna(author):
                author_edited.append(np.nan)
            elif author in mapping and mapping[author]:
                author_edited.append(mapping[author].lower())
            elif isinstance(author, str):
                author_edited.append(author.lower())
            else:
                author_edited.append(author)
    df['author_edited'] = author_edited
    return df

partipris = create_author_edited_column(partipris)

# %%
partipris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source_file      698 non-null    object
#  1   author           695 non-null    object
#  2   title            698 non-null    object
#  3   page_range       698 non-null    object
#  4   text             698 non-null    object
#  5   volume_number    593 non-null    object
#  6   issue_number     698 non-null    object
#  7   season_or_month  698 non-null    object
#  8   year             698 non-null    int64
#  9   author_edited    695 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 54.7+ KB

# %%
# Let's look at all the unique values in author_edited

unique_authors = partipris['author_edited'].unique()
print(f"Number of unique authors in author_edited: {len(unique_authors)}")
for author in unique_authors:
    if pd.notna(author):
        print(author)
# Out:
# Number of unique authors in author_edited: 190
# parti pris editorial team
# pierre maheu
# jean-marc piotte
# yvon dionne
# paul chamberland
# andré brochu
# andré major
# pierre vadeboncoeur
# robert maheu
# denys arcand
# jacques ferron
# jacques godbout
# camille limoges
# parti pris editorial board
# georges schoeters
# gaston miron
# jacques brault
# paul-marie lapointe
# robert mackay
# jean-claude lebel
# parti pris
# pierre bourgault
# laurent girouard
# jacques berque
# andré balestard
# patrick straram
# hubert aquin
# gilles vigneault
# nina bruneau
# luc racine
# michel van schendel
# unknown
# gérald godin
# jacques allard
# parti pris / j.-m.p.
# jean-marc piotte, paul chamberland
# roger nantel
# gilles carle
# clément perron
# gilles groulx
# jacques renaud
# jean-robert rémillard
# jan depocas
# éditorial
# jean-claude lapointe
# roger guy
# serge grenier
# pierre lefebvre
# andrée benoist
# réginald hamel
# archival document
# charles gill
# albert laberge
# la direction.
# raymond villeneuve
# jacques lebrecque
# andré garand
# jacques poisson
# gilles derome
# alain bouchard
# jacques trudel
# pierre prézeau
# reggie chartrand
# jean-pierre trempe
# club parti pris
# stéphane venne
# pierre charbonneau
# andrée ferretti
# mario dumais
# patrice lumumba
# jacques-victor morin
# michael mc andrew
# michael draper
# claude girouard
# gilles thérien
# georges balandier
# le bureau exécutif
# madeleine richer
# luc dufresne
# j.m.
# parti-pris
# rené beaudin
# déclaration
# marcel rioux
# jean-pascal benoist
# pierre vallières
# jacques-m. langlais, c.s.c.
# mouvement de libération populaire et de la revue parti pris
# andrée ferretti-bertrand
# mario dumais, robert tremblay
# collectif (not explicitly stated, but implies common effort)
# pierre hébert
# emmanuel garon
# charles gagnon
# jean marc piotte
# michel guénard
# pierre vadboncoeur
# germain canuel
# bernard s. mergler
# michel mill
# gaétan tremblay
# m.cheddi jagan
# n.fortin
# michel euvrard
# g.m.
# andré pollender
# p.m.
# la rédaction
# r.-g. m.
# équipe de rédaction
# campus libre j.e.
# gilles des marchais
# guy kosak
# non spécifié
# yvon hussereau
# jean racine
# p.
# j. d.
# j. f.
# robert boily
# yordan kostakeff
# gerald godin
# various
# claude gauvreau
# denis vanier
# claude péloquin
# raoul j. letiecq
# gabriel gagnon
# bertrand lebel
# gaëtan tremblay
# jean marchand
# raoul duguay
# anonymous
# yvon husereau
# parti pris / g.t.
# michel bernard
# charles gagnon, pierre vallieres
# p.p.
# l'équipe parti pris; patrick straram; gaëtan tremblay
# p.p. / g. t., p. m.
# guy bourassa
# gilles dostaler
# gilles bourque et luc racine
# pierre desrosiers
# lise rochon
# philippe bernard
# gilles bourque; michel pichette; narcisso pizarro; luc racine
# jean-louis chabot
# ronald sabourin
# nicole gagnon
# le comité de rédaction
# i. r.
# luc racine, michel pichette, narciso pizarro, gilles bourque
# ch. g.
# philippe bernard, gaëtan tremblay
# andrée paul, raoul duguay
# pierre r. desrosiers
# camil guy
# p. p.
# gilles bourque
# thérèse dumouchel
# che guevara
# ph. b.
# ernesto "che" guevara
# rené dal magro
# sh. b.
# parti pris/p.m.
# françois bachand
# andrée bertrand-ferreti
# robert tremblay et pierre renaud
# marcel pépin
# andré théberge
# g.d.
# jean-guy loranger - luc racine
# robert tremblay
# gabriel gagnon, jean-guy loranger, louis gendreau, rémi savard, gaétan dufour, gilles dostaler
# pierre renaud, robert tremblay
# roger soublière
# pierre baerel
# serge garant
# andrée paul
# un fonctionnaire (québec)
# gérald fortin
# jean pierre lefevre
# raoul roy
# françois aquin
# r. s.
# levesque
# jean-guy loranger

# %% [markdown]
# This is alreay better but we are not done yet. Let's look at all the names that refer to the editorial team. They appear in many versions and some with dashes like parti pris / j.-m.p.
#
    "gabriel gagnon, jean-guy loranger, louis gendreau, rémi savard, gaétan dufour, gilles dostaler": "gabriel gagnon; jean-guy loranger; louis gendreau; rémi savard; gaétan dufour; gilles dostaler",
    "pierre renaud, robert tremblay": "pierre renaud; robert tremblay",
    "gilles bourque et luc racine": "gilles bourque; luc racine",
    "robert tremblay et pierre renaud": "robert tremblay; pierre renaud",
    "jean-guy loranger - luc racine": "jean-guy loranger; luc racine",
    "gilles bourque; michel pichette; narcisso pizarro; luc racine": "gilles bourque; michel pichette; narcisso pizarro; luc racine",
    # Remove extra spaces and standardize
    "l'équipe parti pris": "parti pris",
    "le bureau exécutif": "parti pris",
    "équipe de rédaction": "parti pris",
    "la rédaction": "parti pris",
    "la direction.": "parti pris",
}

# %%
# Let's apply this to our author_edited column

def map_author_name(name):
    if pd.isna(name):
        return name
    key = name.strip().lower()
    return author_name_mapping.get(key, key)

partipris['author_edited'] = partipris['author_edited'].apply(map_author_name)

# %%
unique_authors = partipris['author_edited'].unique()
print(f"Number of unique authors in author_edited: {len(unique_authors)}")
for author in unique_authors:
    if pd.notna(author):
        print(author)
# Out:
# Number of unique authors in author_edited: 169
# parti pris
# pierre maheu
# jean-marc piotte
# yvon dionne
# paul chamberland
# andré brochu
# andré major
# pierre vadeboncoeur
# robert maheu
# denys arcand
# jacques ferron
# jacques godbout
# camille limoges
# georges schoeters
# gaston miron
# jacques brault
# paul-marie lapointe
# robert mackay
# jean-claude lebel
# pierre bourgault
# laurent girouard
# jacques berque
# andré balestard
# patrick straram
# hubert aquin
# gilles vigneault
# nina bruneau
# luc racine
# michel van schendel
# gérald godin
# jacques allard
# parti pris; j.-m.p.
# jean-marc piotte; paul chamberland
# roger nantel
# gilles carle
# clément perron
# gilles groulx
# jacques renaud
# jean-robert rémillard
# jan depocas
# jean-claude lapointe
# roger guy
# serge grenier
# pierre lefebvre
# andrée benoist
# réginald hamel
# charles gill
# albert laberge
# raymond villeneuve
# jacques lebrecque
# andré garand
# jacques poisson
# gilles derome
# alain bouchard
# jacques trudel
# pierre prézeau
# reggie chartrand
# jean-pierre trempe
# stéphane venne
# pierre charbonneau
# andrée ferretti
# mario dumais
# patrice lumumba
# jacques-victor morin
# michael mc andrew
# michael draper
# claude girouard
# gilles thérien
# georges balandier
# madeleine richer
# luc dufresne
# j.m.
# rené beaudin
# marcel rioux
# jean-pascal benoist
# pierre vallières
# jacques-m. langlais, c.s.c.
# andrée ferretti-bertrand
# mario dumais; robert tremblay
# pierre hébert
# emmanuel garon
# charles gagnon
# jean marc piotte
# michel guénard
# pierre vadboncoeur
# germain canuel
# bernard s. mergler
# michel mill
# gaétan tremblay
# m.cheddi jagan
# n.fortin
# michel euvrard
# g.m.
# andré pollender
# p.m.
# r.-g.m.
# campus libre j.e.
# gilles des marchais
# guy kosak
# yvon hussereau
# jean racine
# j.d.
# j.f.
# robert boily
# yordan kostakeff
# gerald godin
# claude gauvreau
# denis vanier
# claude péloquin
# raoul j. letiecq
# gabriel gagnon
# bertrand lebel
# gaëtan tremblay
# jean marchand
# raoul duguay
# yvon husereau
# parti pris; g.t.
# michel bernard
# charles gagnon; pierre vallieres
# parti pris; patrick straram; gaëtan tremblay
# parti pris; g.t.; p.m.
# guy bourassa
# gilles dostaler
# gilles bourque; luc racine
# pierre desrosiers
# lise rochon
# philippe bernard
# gilles bourque; michel pichette; narcisso pizarro; luc racine
# jean-louis chabot
# ronald sabourin
# nicole gagnon
# i.r.
# luc racine; michel pichette; narciso pizarro; gilles bourque
# ch.g.
# philippe bernard; gaëtan tremblay
# andrée paul; raoul duguay
# pierre r. desrosiers
# camil guy
# gilles bourque
# thérèse dumouchel
# che guevara
# ph.b.
# ernesto "che" guevara
# rené dal magro
# sh.b.
# parti pris; p.m.
# françois bachand
# andrée bertrand-ferreti
# robert tremblay; pierre renaud
# marcel pépin
# andré théberge
# g.d.
# jean-guy loranger; luc racine
# robert tremblay
# gabriel gagnon; jean-guy loranger; louis gendreau; rémi savard; gaétan dufour; gilles dostaler
# pierre renaud; robert tremblay
# roger soublière
# pierre baerel
# serge garant
# andrée paul
# un fonctionnaire (québec)
# gérald fortin
# jean pierre lefevre
# raoul roy
# françois aquin
# r.s.
# levesque
# jean-guy loranger

# %% [markdown]
# Already a lot cleaner, especially all the Parti Pris names. But we can do better, especially since there are typos and small spelling errors in the names like `pierre vadboncoeur`. Let's also see how many times they appear before we attempt another clean up.

# %%
# Let's also see how many times they appear before we attempt another clean up

author_counts = partipris['author_edited'].value_counts(dropna=False)
print("Author name frequencies in author_edited:")
for author, count in author_counts.items():
    print(f"{author}: {count}")
# Out:
# Author name frequencies in author_edited:
# parti pris: 106
# patrick straram: 48
# pierre maheu: 35
# gérald godin: 33
# paul chamberland: 27
# luc racine: 22
# gabriel gagnon: 19
# gaëtan tremblay: 19
# andré major: 16
# philippe bernard: 15
# jean-marc piotte: 13
# jacques ferron: 13
# laurent girouard: 12
# michel euvrard: 11
# thérèse dumouchel: 10
# andré brochu: 10
# denys arcand: 9
# robert maheu: 8
# jacques godbout: 8
# jacques brault: 8
# raoul duguay: 7
# gilles bourque: 7
# gilles dostaler: 6
# jacques trudel: 6
# pierre lefebvre: 6
# jan depocas: 6
# jacques renaud: 5
# gaston miron: 5
# jacques allard: 5
# mario dumais: 5
# g.m.: 4
# guy bourassa: 4
# gaétan tremblay: 4
# charles gagnon: 4
# françois aquin: 4
# michael draper: 4
# michel guénard: 4
# camille limoges: 4
# pierre vadeboncoeur: 4
# pierre desrosiers: 3
# pierre vallières: 3
# j.d.: 3
# rené beaudin: 3
# yvon dionne: 3
# raoul roy: 3
# p.m.: 3
# nan: 3
# jacques-victor morin: 2
# michel mill: 2
# hubert aquin: 2
# gilles vigneault: 2
# robert tremblay: 2
# jacques berque: 2
# robert mackay: 2
# andré théberge: 2
# michel van schendel: 2
# réginald hamel: 2
# jacques poisson: 2
# jean-robert rémillard: 2
# roger guy: 2
# andrée benoist: 2
# yvon hussereau: 2
# jean-claude lebel: 2
# i.r.: 1
# nicole gagnon: 1
# ronald sabourin: 1
# pierre bourgault: 1
# jean-louis chabot: 1
# jean marchand: 1
# gilles bourque; michel pichette; narcisso pizarro; luc racine: 1
# parti pris; patrick straram; gaëtan tremblay: 1
# lise rochon: 1
# yvon husereau: 1
# parti pris; g.t.: 1
# michel bernard: 1
# gilles bourque; luc racine: 1
# paul-marie lapointe: 1
# luc racine; michel pichette; narciso pizarro; gilles bourque: 1
# charles gagnon; pierre vallieres: 1
# parti pris; g.t.; p.m.: 1
# georges schoeters: 1
# gilles groulx: 1
# ch.g.: 1
# g.d.: 1
# levesque: 1
# r.s.: 1
# jean pierre lefevre: 1
# gérald fortin: 1
# un fonctionnaire (québec): 1
# andrée paul: 1
# serge garant: 1
# pierre baerel: 1
# roger soublière: 1
# pierre renaud; robert tremblay: 1
# gabriel gagnon; jean-guy loranger; louis gendreau; rémi savard; gaétan dufour; gilles dostaler: 1
# jean-guy loranger; luc racine: 1
# marcel pépin: 1
# philippe bernard; gaëtan tremblay: 1
# robert tremblay; pierre renaud: 1
# andrée bertrand-ferreti: 1
# françois bachand: 1
# parti pris; p.m.: 1
# sh.b.: 1
# rené dal magro: 1
# ernesto "che" guevara: 1
# ph.b.: 1
# che guevara: 1
# camil guy: 1
# pierre r. desrosiers: 1
# andrée paul; raoul duguay: 1
# bertrand lebel: 1
# j.f.: 1
# raoul j. letiecq: 1
# luc dufresne: 1
# georges balandier: 1
# gilles thérien: 1
# claude girouard: 1
# parti pris; j.-m.p.: 1
# michael mc andrew: 1
# patrice lumumba: 1
# jean-marc piotte; paul chamberland: 1
# andrée ferretti: 1
# pierre charbonneau: 1
# stéphane venne: 1
# jean-pierre trempe: 1
# reggie chartrand: 1
# pierre prézeau: 1
# roger nantel: 1
# alain bouchard: 1
# gilles derome: 1
# andré garand: 1
# jacques lebrecque: 1
# raymond villeneuve: 1
# albert laberge: 1
# charles gill: 1
# gilles carle: 1
# serge grenier: 1
# jean-claude lapointe: 1
# clément perron: 1
# madeleine richer: 1
# j.m.: 1
# claude péloquin: 1
# marcel rioux: 1
# denis vanier: 1
# claude gauvreau: 1
# gerald godin: 1
# yordan kostakeff: 1
# robert boily: 1
# jean racine: 1
# guy kosak: 1
# gilles des marchais: 1
# campus libre j.e.: 1
# r.-g.m.: 1
# andré pollender: 1
# andré balestard: 1
# n.fortin: 1
# m.cheddi jagan: 1
# bernard s. mergler: 1
# germain canuel: 1
# pierre vadboncoeur: 1
# nina bruneau: 1
# jean marc piotte: 1
# emmanuel garon: 1
# pierre hébert: 1
# mario dumais; robert tremblay: 1
# andrée ferretti-bertrand: 1
# jacques-m. langlais, c.s.c.: 1
# jean-pascal benoist: 1
# jean-guy loranger: 1

# %% [markdown]
# Let's do another round of mapping with GPT-4.1 to get the typos corrected and then we also have some usual suspects. Like `p.m.` is clearly `pierre maheu`. Some of the rest of the intials have obvious candidates too. Let's do another round of mapping with GPT-4.1

# %%
# This also showed that some author names were NaN and became nan while lowercasing
# or they were nan to begin with. This was probably because there were no names associated with
# the texts that Gemini 2.5 could extract. We should map them back to NaN in the proper way.

import numpy as np
# Ensure NaN values in author_edited are not converted to the string "nan"
partipris['author_edited'] = partipris['author_edited'].replace({'nan': np.nan, '': np.nan})

# %%
# Usual suspects mapping and typos

# Mapping for author typos, initials, and variants
author_typo_initials_mapping = {
    # Initials to full names based on what we know of the corpus and who the potential names are
    "p.m.": "pierre maheu",
    "j.m.": "jean-marc piotte",
    "g.t.": "gaëtan tremblay",
    "ph.b.": "philippe bernard",
    "ch.g.": "charles gagnon",
    "g.m.": "gaston miron",
    "j.d.": "jan depocas",
    "parti pris; g.t.; p.m." : "parti pris; gaëtan tremblay; pierre maheu",
    "parti pris; g.t.": "parti pris; gaëtan tremblay",
    "parti pris; j.-m.p.": "parti pris; jean-marc piotte",
    # Typos and accent/spacing variants
    "gerald godin": "gérald godin",
    "pierre vallieres": "pierre vallières",
    "yvon husereau": "yvon hussereau",
    "pierre vadboncoeur": "pierre vadeboncoeur",
    "andrée bertrand-ferreti": "andrée ferretti-bertrand",
    "jean marc piotte": "jean-marc piotte",
    "gaétan tremblay": "gaëtan tremblay",
    "gaetan tremblay": "gaëtan tremblay",
    "charles gagnon; pierre vallieres": "charles gagnon; pierre vallières",
}

# %%
def map_author_typo_initials(name):
    if pd.isna(name):
        return name
    key = name.strip().lower()
    return author_typo_initials_mapping.get(key, key)

partipris['author_edited'] = partipris['author_edited'].apply(map_author_typo_initials)

# %%
author_counts = partipris['author_edited'].value_counts(dropna=False)
print(f"Number of unique authors in author_edited after typo mapping: {len(author_counts)}")
print("Author name frequencies in author_edited:")
for author, count in author_counts.items():
    print(f"{author}: {count}")
# Out:
# Number of unique authors in author_edited after typo mapping: 157
# Author name frequencies in author_edited:
# parti pris: 106
# patrick straram: 48
# pierre maheu: 38
# gérald godin: 34
# paul chamberland: 27
# gaëtan tremblay: 23
# luc racine: 22
# gabriel gagnon: 19
# andré major: 16
# philippe bernard: 16
# jean-marc piotte: 15
# jacques ferron: 13
# laurent girouard: 12
# michel euvrard: 11
# andré brochu: 10
# thérèse dumouchel: 10
# denys arcand: 9
# gaston miron: 9
# jan depocas: 9
# jacques godbout: 8
# jacques brault: 8
# robert maheu: 8
# gilles bourque: 7
# raoul duguay: 7
# pierre lefebvre: 6
# gilles dostaler: 6
# jacques trudel: 6
# charles gagnon: 5
# mario dumais: 5
# pierre vadeboncoeur: 5
# jacques renaud: 5
# jacques allard: 5
# michel guénard: 4
# françois aquin: 4
# guy bourassa: 4
# camille limoges: 4
# michael draper: 4
# nan: 3
# yvon dionne: 3
# pierre desrosiers: 3
# raoul roy: 3
# yvon hussereau: 3
# rené beaudin: 3
# pierre vallières: 3
# jacques-victor morin: 2
# andré théberge: 2
# andrée ferretti-bertrand: 2
# michel mill: 2
# jacques poisson: 2
# jacques berque: 2
# réginald hamel: 2
# jean-claude lebel: 2
# roger guy: 2
# andrée benoist: 2
# jean-robert rémillard: 2
# robert mackay: 2
# michel van schendel: 2
# hubert aquin: 2
# gilles vigneault: 2
# robert tremblay: 2
# gilles bourque; luc racine: 1
# g.d.: 1
# lise rochon: 1
# gérald fortin: 1
# un fonctionnaire (québec): 1
# andrée paul: 1
# jean pierre lefevre: 1
# parti pris; gaëtan tremblay; pierre maheu: 1
# serge garant: 1
# parti pris; patrick straram; gaëtan tremblay: 1
# charles gagnon; pierre vallières: 1
# michel bernard: 1
# parti pris; gaëtan tremblay: 1
# r.s.: 1
# jean marchand: 1
# bertrand lebel: 1
# levesque: 1
# gilles bourque; michel pichette; narcisso pizarro; luc racine: 1
# roger soublière: 1
# pierre baerel: 1
# gabriel gagnon; jean-guy loranger; louis gendreau; rémi savard; gaétan dufour; gilles dostaler: 1
# claude péloquin: 1
# robert tremblay; pierre renaud: 1
# françois bachand: 1
# jean-guy loranger; luc racine: 1
# parti pris; p.m.: 1
# sh.b.: 1
# rené dal magro: 1
# ernesto "che" guevara: 1
# che guevara: 1
# camil guy: 1
# jean-louis chabot: 1
# pierre renaud; robert tremblay: 1
# pierre r. desrosiers: 1
# andrée paul; raoul duguay: 1
# philippe bernard; gaëtan tremblay: 1
# luc racine; michel pichette; narciso pizarro; gilles bourque: 1
# i.r.: 1
# nicole gagnon: 1
# ronald sabourin: 1
# marcel pépin: 1
# raoul j. letiecq: 1
# mario dumais; robert tremblay: 1
# denis vanier: 1
# serge grenier: 1
# stéphane venne: 1
# jean-pierre trempe: 1
# reggie chartrand: 1
# pierre prézeau: 1
# alain bouchard: 1
# gilles derome: 1
# andré garand: 1
# jacques lebrecque: 1
# raymond villeneuve: 1
# albert laberge: 1
# charles gill: 1
# jean-claude lapointe: 1
# claude gauvreau: 1
# gilles groulx: 1
# clément perron: 1
# gilles carle: 1
# roger nantel: 1
# jean-marc piotte; paul chamberland: 1
# parti pris; jean-marc piotte: 1
# nina bruneau: 1
# andré balestard: 1
# pierre bourgault: 1
# paul-marie lapointe: 1
# georges schoeters: 1
# pierre charbonneau: 1
# andrée ferretti: 1
# patrice lumumba: 1
# michael mc andrew: 1
# yordan kostakeff: 1
# robert boily: 1
# j.f.: 1
# jean racine: 1
# guy kosak: 1
# gilles des marchais: 1
# campus libre j.e.: 1
# r.-g.m.: 1
# andré pollender: 1
# n.fortin: 1
# m.cheddi jagan: 1
# bernard s. mergler: 1
# germain canuel: 1
# emmanuel garon: 1
# pierre hébert: 1
# jacques-m. langlais, c.s.c.: 1
# jean-pascal benoist: 1
# marcel rioux: 1
# luc dufresne: 1
# madeleine richer: 1
# georges balandier: 1
# gilles thérien: 1
# claude girouard: 1
# jean-guy loranger: 1

# %% [markdown]
# Much cleaner! This whole process of author name normalization is rather relative and specific to the corpus. We chose to normalize all the cases of Parti Pris multiauthorship to Parti Pris only, unless otherwise specified because our goal is to make it easier for us to count authors.
#
# The first part of the author name normalization, mapping initials to author names per issue, was the more reliable and scaleable part of the process.
#
# GPT-4.1 supported mapping of names could have also been done manually and it was indeed edited manually because it was easier to sort out names when there are less than 200 unique names. It is however not as easily scalable and requires knowledge of the corpus.

# %%
# saving the corpus
partipris.to_csv('../data/processed/partipris_v5.csv', index=False)

# %% [markdown]
# ### Metadata Clean Up
#
# Months and seasons as integers
# figure out how to represent dual month issues
