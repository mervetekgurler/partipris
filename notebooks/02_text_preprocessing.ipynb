# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# This notebook contains the text preprocessing or data cleaning step for the Parti Pris corpus. At the end of the previous notebook, we were

# %% [markdown]
# Metadata first from ToC to get year, month, volume, issue, etc -> connected to the texts through the 'source_file'

# %%
skip_files = {
    "163122_1-1964-09-01.json",
    "163122_1-1964-12-01.json",
    "163122_2-1966-06.json"
}

# %%
import re
import os
import json
import pandas as pd

# %%
# read the json files from data/transcriptions

transcriptions_dir = "../data/transcriptions"
json_files = [f for f in os.listdir(transcriptions_dir) if f.endswith('.json')]

data = []
for file in json_files:
    with open(os.path.join(transcriptions_dir, file), 'r', encoding='utf-8') as f:
        entry = json.load(f)
        if isinstance(entry, list):
            for item in entry:
                item['source_file'] = file
                data.append(item)
        else:
            entry['source_file'] = file
            data.append(entry)

df = pd.DataFrame(data)
df.head()
# Out:
#              author                        title page_range  \
# 0        parti pris              manifeste 64-65       4-17
# 1     la direction.            lettre au lecteur      18-19
# 2  paul chamberland            bilan d'un combat      20-35
# 3  jean-marc piotte   autocritique de parti pris      36-44
# 4      pierre maheu  notes pour une politisation      45-56
#
#                                                 text            source_file
# 0  manifeste 64-65 Toute révolution détruit l'anc...  163122_1-1964-09.json
# 1  lettre au lecteur parti pris se prépare à une ...  163122_1-1964-09.json
# 2  bilan d'un combat paul chamberland Nous lutton...  163122_1-1964-09.json
# 3  autocritique de parti pris jean-marc piotte Pi...  163122_1-1964-09.json
# 4  notes pour une politisation pierre maheu Dans ...  163122_1-1964-09.json

# %%
# 163122_1-1964-09-01.json is basically empty because it is an overview of the whole year
# we will remove it
df = df[df['source_file'] != '163122_1-1964-09-01.json']

# %%
# 163122_2-1966-06.json is also empty. According to BAnQ, it was never published, so the record
# states "non paru". We will remove it as well
df = df[df['source_file'] != '163122_2-1966-06.json']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 0 to 826
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   author       707 non-null    object
#  1   title        707 non-null    object
#  2   page_range   707 non-null    object
#  3   text         707 non-null    object
#  4   source_file  707 non-null    object
# dtypes: object(5)
# memory usage: 33.1+ KB

# %%
# look at the entries with pierre vallieres
df[df['author'].str.lower().str.contains('pierre vallieres')]
# Out:
#                                author  \
# 434  Charles GAGNON, Pierre VALLIERES
#
#                                                  title page_range  \
# 434  document Grève de la Fain pour la reconnaissan...      88-91
#
#                                                   text  \
# 434  document Grève de la Faim pour la reconnaissan...
#
#                  source_file
# 434  163122_2-1966-11-B.json

# %%
df[df['author'].str.lower().str.contains('vallières')]
# Out:
#                author                              title page_range  \
# 103  pierre vallières  les grèves de l'été, un tournant?        103
# 438  Pierre Vallières              Cuba révolutionnaire.      21-27
# 692  pierre vallières  les grèves de l'été, un tournant?      40-40
# 737  pierre vallières          pour l'union de la gauche      51-52
#
#                                                   text  \
# 103
# 438  La réunion en janvier 1966 de la première con ...
# 692  Il est trop tôt pour affirmer avec certitude q...
# 737  Les militants de Révolution québécoise ont déc...
#
#                  source_file
# 103  163122_1-1965-08-A.json
# 438    163122_2-1967-09.json
# 692  163122_1-1965-08-B.json
# 737  163122_1-1965-06-B.json

# %%
# Convert author names to lowercase and get unique authors
df['author'] = df['author'].str.lower()
unique_authors = df['author'].unique()
print(unique_authors)
# Out:
# ['parti pris' 'la direction.' 'paul chamberland' 'jean-marc piotte'
#  'pierre maheu' 'raymond villeneuve' 'laurent girouard'
#  'jacques lebrecque' 'andré major' 'denys arcand' 'yvon hussereau'
#  'jean racine' 'jacques trudel' 'gérald godin' 'michel euvrard'
#  'patrick straram' 'g. g.' 'p.' 'j. d.' 'm. g...' 'p. s' 'p. s.' ''
#  'j. f.' 'éditorial' 'pierre lefebvre' 'le bureau exécutif' 'mario dumais'
#  'jacques poisson' 'andré brochu' 'déclaration' 'jacques brault'
#  'marcel rioux' 'jacques ferron' 'jean-pascal benoist' 'gaétan tremblay'
#  'pierre vadeboncoeur' 'un fonctionnaire (québec)' 'gérald fortin'
#  'jacques godbout' 'jean pierre lefevre' 'guy bourassa' 'raoul roy'
#  'jan depocas' 'françois aquin' 'r. s.' 'p.p. / g. t., p. m.'
#  'gilles dostaler' 'gilles bourque et luc racine' 'pierre desrosiers'
#  'jean-robert rémillard' 'jean-claude lapointe' 'roger guy'
#  'robert mackay' 'camille limoges' 'serge grenier'
#  'mouvement de libération populaire et de la revue parti pris'
#  'andrée bertrand-ferretti' 'mario dumais, robert tremblay'
#  'léandre bergeron' 'pierre vallières' 'pierre hébert' 'emmanuel garon'
#  'jacques allard' 'charles gagnon' 'stéphane venne' 'pierre charbonneau'
#  'andrée ferretti' 'patrice lumumba' 'luc racine'
#  'gilles bourque; michel pichette; narcisso pizarro; luc racine'
#  'jean-louis chabot' 'ronald sabourin' 'nicole gagnon' 'gilles carle'
#  'clément perron' 'gilles groulx' 'jacques renaud' 'robert maheu'
#  'unknown' 'pierre prézeau' 'reggie chartrand' 'jean-pierre trempe'
#  'club parti pris' 'équipe de rédaction' 'campus libre j.e.'
#  'rené beaudin' 'gilles des marchais' 'guy kosak' 'non spécifié' 'm. d.'
#  'michael draper' 'madeleine richer' 'luc dufresne' 'j.m.' 'parti-pris'
#  'levesque' 'gaston miron' 'andré théberge' 'la rédaction'
#  'gaëtan tremblay' 'gabriel gagnon' 'bertrand lebel'
#  'jacques-victor morin' 'michael mc andrew' 'parti pris editorial board'
#  'georges schoeters' 'paul-marie lapointe' 'jean-claude lebel'
#  'marcel pépin' 'p.m.' 'parti pris / j.-m.p.' 'jacques berque'
#  'michel van schendel' 'jean-marc piotte, paul chamberland' 'roger nantel'
#  'che guevara' 'philippe bernard' 'gilles bourque' 'thérèse dumouchel'
#  'raoul duguay' 'parti pris/p.m.' 'françois bachand'
#  'andrée bertrand-ferreti' 'robert tremblay et pierre renaud'
#  'andrée benoist' 'parti pris / g.t.' 'hubert aquin'
#  'parti pris editorial team' 'yvon dionne' 'jean marc piotte'
#  'michel guénard' 'pierre vadboncoeur' 'germain canuel'
#  'le comité de rédaction' 'i. r.' 'pierre renaud, robert tremblay'
#  'rené dal magro' 'p.s.' 'claude girouard' 'gilles thérien'
#  'georges balandier' 'gilles vigneault' 'nina bruneau'
#  'bernard s. mergler' 'michel mill' 'm.cheddi jagan' 'n.fortin' 'g.g.'
#  'g.m.' 'luc racine, michel pichette, narciso pizarro, gilles bourque'
#  'roger soublière' 'pierre baerel' 'serge garant' 'andrée paul'
#  'claude gauvreau' 'denis vanier' 'claude péloquin' 'm. e.'
#  'raoul j. letiecq' 'sh. b.' 'michel bernard'
#  'charles gagnon, pierre vallieres' 'réginald hamel' 'archival document'
#  'charles gill' 'albert laberge' 'p.p.' 'g.t.'
#  "l'équipe parti pris, patrick straram et gaëtan tremblay." 'ch. g.'
#  'philippe bernard, gaëtan tremblay' 'andrée paul, raoul duguay'
#  'pierre bourgault' 'andré balestard' 'g.d.'
#  'jean-guy loranger - luc racine' 'robert tremblay'
#  'gabriel gagnon, jean-guy loranger, louis gendreau, rémi savard, gaétan dufour, gilles dostaler'
#  'théo chentrier' 'monique miller' 'roger farnier' 'simon richer, m.d.'
#  'lucien auclair' 'mme armand sauvé' 'chantal gagnon'
#  'mouvement laïque de langue française' 'paul-henri spaak' 'alain hogue'
#  'ph. b.' 'ernesto "che" guevara' 'andré pollender' 'p. c.' 'p.c.'
#  'r.-g. m.' 'various authors' 'yvon husereau' 'andrée ferretti-bertrand'
#  'collectif (not explicitly stated, but implies common effort)'
#  'alain bouchard' 'pierre r. desrosiers' 'camil guy'
#  'jacques-m. langlais, c.s.c.' 'jean-guy loranger' 'raymond lévesque'
#  'lise rochon' 'georges kostakeff' 'p. p.' 'g. t.' 'p. m.' 'andré garand'
#  'gilles derome' 'parti pris / p.m.' 'robert boily']

# %%
# sort unique authors by article count
author_counts = df['author'].value_counts()
sorted_authors = author_counts.sort_values(ascending=False)
print(sorted_authors)
# Out:
# author
# patrick straram                                                 32
# pierre maheu                                                    29
# unknown                                                         29
# gérald godin                                                    27
# parti pris                                                      22
#                                                                 ..
# collectif (not explicitly stated, but implies common effort)     1
# andrée ferretti-bertrand                                         1
# yvon husereau                                                    1
# various authors                                                  1
# robert boily                                                     1
